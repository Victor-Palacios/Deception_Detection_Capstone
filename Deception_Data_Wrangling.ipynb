# %%
# Packages for Data Wrangling
import numpy as np
import pandas as pd
import os
import re
from collections import Counter

# For graphs
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Use cleaner absolute path to find file
path = os.path.abspath('politifact.csv')
df = pd.read_csv(path, index_col=0)

# %%
# Check for null values and total number of rows
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16611 entries, 0 to 16610
# Data columns (total 4 columns):
# statement    16611 non-null object
# source       16611 non-null object
# link         16611 non-null object
# veracity     16611 non-null object
# dtypes: object(4)
# memory usage: 648.9+ KB

# %% [markdown]
# # Initially 16611 rows of non-null data

# %%
# to see statement in full
pd.set_option('display.max_colwidth', 200) 

# See sample of data
df.head(3)
# Out:
#                                                                                                                                                                                      statement  \
# 0                                             Says that in 1770 "British parliament banned lipstick, saying it had the power to seduce men into marriage, which was classified as witchcraft."
# 1  Says Ann Landers said, "At age 20, we worry about what others think of us. At age 40, we don’t care what they think. At age 60, we discover that they have not been thinking of us at all."
# 2                                                                                                                                                   "General Motors is making record profits."
#
#            source  \
# 0  Facebook posts
# 1     Viral image
# 2      Glenn Kage
#
#                                                                                                               link  \
# 0  /facebook-fact-checks/statements/2019/oct/25/facebook-posts/no-british-parliament-didnt-ban-witchcraft-lipstic/
# 1           /facebook-fact-checks/statements/2019/oct/25/viral-image/no-evidence-ann-landers-said-quote-about-age/
# 2                  /missouri/statements/2019/oct/25/glenn-kage/general-motors-profits-have-been-record-setting-no/
#
#          veracity
# 0  Pants on Fire!
# 1           False
# 2       Half-True

# %%
# check groups that exist in veracity column
df.veracity.value_counts()
# Out:
# False             3274
# Half-True         3158
# Mostly True       3010
# Mostly False      2756
# True              2340
# Pants on Fire!    1817
# Full Flop          159
# Half Flip           70
# No Flip             27
# Name: veracity, dtype: int64

# %%
# Full Flop, Half Flip, & No Flip have nothing to do with veracity; remove them
# Half-True, Mostly True, & Mostly False are non-exclusive groups; remove them
ver_df = df[df.isin(['True',
                    'False',
                    'Pants on Fire!']).any(axis=1)]

# %%
# The total number of rows should sum to 7431 (false(3274) + true(2340) + pants on fire(1817) = 7431)
ver_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7431 entries, 0 to 16610
# Data columns (total 4 columns):
# statement    7431 non-null object
# source       7431 non-null object
# link         7431 non-null object
# veracity     7431 non-null object
# dtypes: object(4)
# memory usage: 290.3+ KB

# %% [markdown]
# # 7431 rows survived

# %%
# check if large imbalance in the 3 classes
ver_df.veracity.value_counts()
# Out:
# False             3274
# True              2340
# Pants on Fire!    1817
# Name: veracity, dtype: int64

# %%
# randomly sample 10 rows
ver_df.iloc[0:100:10]
# Out:
#                                                                                                                                             statement  \
# 0    Says that in 1770 "British parliament banned lipstick, saying it had the power to seduce men into marriage, which was classified as witchcraft."
# 14                                          Barnes & Noble and Target have the book "If You Give a Pig the White House" in their children’s sections.
# 28                                                 Says California has "30% or a third of the country’s people living at or below the poverty level."
# 49               Says Fox News anchor Shepard Smith stepped down after Attorney General William Barr "had a closed door meeting with Rupert Murdoch."
# 62                   Says the sons of Nancy Pelosi, Mitt Romney and John Kerry are all on the boards of "energy companies doing business in Ukraine."
# 74                                  Says Rep. Adam Schiff was "complicit in EDITING AND COMPOSING THE ‘WHISTLEBLOWER COMPLAINT’ BEFORE IT WAS FILED."
# 90                        Siobhan Dunnavant "wrote the Republican bill that would let insurance companies deny coverage for pre-existing conditions."
# 105           Says Gov. Tony Evers vetoed a school computer program, "saying it would be better spent in urban districts like Madison and Milwaukee."
# 119                                                         Says a photo shows that climate change protesters left trash all over their protest side.
# 141                                            "U.S. agricultural & food exports are expected to increase more than $2 billion annually under #USMCA"
#
#              source  \
# 0    Facebook posts
# 14      Viral image
# 28    Mark Batinick
# 49    The Other 98%
# 62   Facebook posts
# 74   Facebook posts
# 90     Rodman Debra
# 105  Rob Swearingen
# 119  Facebook posts
# 141       Roy Blunt
#
#                                                                                                                 link  \
# 0    /facebook-fact-checks/statements/2019/oct/25/facebook-posts/no-british-parliament-didnt-ban-witchcraft-lipstic/
# 14      /facebook-fact-checks/statements/2019/oct/24/viral-image/barnes-noble-isnt-selling-if-you-give-pig-white-ho/
# 28                         /illinois/statements/2019/oct/20/mark-batinick/no-30-nations-poor-dont-reside-california/
# 49                   /punditfact/statements/2019/oct/14/other-98/theres-no-proof-barr-played-role-shepard-smiths-fo/
# 62   /facebook-fact-checks/statements/2019/oct/10/facebook-posts/pelosi-romney-and-kerry-dont-have-sons-working-com/
# 74   /facebook-fact-checks/statements/2019/oct/04/facebook-posts/theres-no-evidence-schiff-helped-write-whistleblow/
# 90                 /virginia/statements/2019/oct/01/rodman-debra/rodman-misstates-dunnavants-short-term-health-insu/
# 105             /wisconsin/statements/2019/sep/27/rob-swearingen/state-rep-exaggerates-claim-gov-tony-evers-veto-sc/
# 119  /facebook-fact-checks/statements/2019/sep/24/facebook-posts/photo-doesnt-show-trash-left-climate-strike-protes/
# 141                   /missouri/statements/2019/sep/17/roy-blunt/report-backs-blunt-claim-2-billion-increase-trade-/
#
#            veracity
# 0    Pants on Fire!
# 14            False
# 28            False
# 49            False
# 62            False
# 74            False
# 90            False
# 105           False
# 119           False
# 141            True

# %% [markdown]
# # Should remove statements that begin with "Says entity said" as there are 2 reasons this may be false: speaker is false or statement is false.

# %% [markdown]
# # Filter for sentences that begin with a quotation

# %%
ver_df[ver_df.statement.str.match(r"\"")==True][0:100:10]
# Out:
#                                                                                                                                                                                                    statement  \
# 3                                                                                                                                                 "14,000 abandoned wind turbines litter the United States."
# 53                                                           "West Virginia Department of Education reported over 10,000 children and youth have been identified as homeless for the 2018-2019 school year."
# 101  "In Congress, Elizabeth Warren introduced 110 bills. 2 passed. Cory Booker introduced 120 bills. 0 passed. Kamala Harris introduced 54 bills. 0 passed. Bernie Sanders never held a job until age 53...
# 180                                                                                                                                 "America has more governors who’ve worn blackface than black governors."
# 233                                                                                                                                   "Yesterday we had the strongest dollar in the history of our country."
# 302                                                                                                                   "Elijah Cummings’ house was broken into after Trump publicly attacked him on Twitter."
# 364       "San Francisco has spent $72.5 million this fiscal year cleaning up human waste and drug paraphernalia" and "there are more drug users on their public needle program than high school graduates."
# 400                                                                                                                 "The wealthiest three families now own more wealth than the bottom half of the country."
# 456                                                                                               "Barack Obama said, ‘If we don’t do something about this president, I will’ at DNC fundraiser last night."
# 507                                                                       "We saw the prison population expand and vacancy rates for correctional officers go from 2.9% to 15.2%" over the last eight years.
#
#                 source  \
# 3          Chain email
# 53         Joe Manchin
# 101     Facebook posts
# 180   Samuel Sinyangwe
# 233       Donald Trump
# 302    Chelsea Handler
# 364  Turning Point USA
# 400     Bernie Sanders
# 456        Viral image
# 507       Chris Taylor
#
#                                                                                                                    link  \
# 3                      /missouri/statements/2019/oct/25/chain-email/no-there-arent-14000-abandoned-wind-turbines-litte/
# 53                      /west-virginia/statements/2019/oct/11/joe-manchin/how-many-west-virginia-students-are-homeless/
# 101     /facebook-fact-checks/statements/2019/sep/27/facebook-posts/social-media-posts-mislead-democratic-senators-rec/
# 180             /punditfact/statements/2019/sep/06/samuel-sinyangwe/its-true-there-are-more-governors-who-have-worn-bl/
# 233              /truth-o-meter/statements/2019/aug/22/donald-trump/donald-trump-incorrect-us-dollar-strongest-its-eve/
# 302              /punditfact/statements/2019/aug/02/chelsea-handler/chelsea-handler-blames-trumps-tweets-break-cumming/
# 364  /facebook-fact-checks/statements/2019/jul/16/turning-point-usa/san-francisco-isnt-spending-725-million-clean-huma/
# 400            /truth-o-meter/statements/2019/jul/03/bernie-sanders/bernie-sanders-target-saying-3-richest-have-much-w/
# 456        /facebook-fact-checks/statements/2019/jun/19/viral-image/no-evidence-obama-said-if-we-dont-do-something-abo/
# 507                  /wisconsin/statements/2019/jun/04/chris-taylor/wisconsin-state-rep-chris-taylor-mark-prison-claim/
#
#            veracity
# 3    Pants on Fire!
# 53             True
# 101           False
# 180            True
# 233           False
# 302           False
# 364           False
# 400            True
# 456           False
# 507            True

# %% [markdown]
# # Precision: 100%
# ## true positive / (true positive + false positive)

# %%
ver_df[ver_df.statement.str.match(r"\"")==False][0:100:10]
# Out:
#                                                                                                                                             statement  \
# 0    Says that in 1770 "British parliament banned lipstick, saying it had the power to seduce men into marriage, which was classified as witchcraft."
# 22                                                                                              AARP backed "federal funding for Planned Parenthood."
# 49               Says Fox News anchor Shepard Smith stepped down after Attorney General William Barr "had a closed door meeting with Rupert Murdoch."
# 68                                    Del. Danica Roem "supported a controversial bill that would have allowed abortion up until the moment of birth.
# 87                                                                         Says a photo shows Beto O’Rourke "in college drunk and pissing his pants."
# 106                                                                                            A photograph shows a woman doing cocaine with a child.
# 123             Quotes Winston Churchill as saying "Diplomacy is the art of telling people to go to hell in such a way that they ask for directions."
# 149                                                                                           Says John Bolton "fundamentally was a man of the left."
# 171                                               Says a Donald Trump tweet credited Gov. Ron DeSantis for Hurricane Dorian’s path away from Florida.
# 191                           Says Winston Churchill said, "You have enemies? Good. That means you’ve stood up for something, sometime in your life."
#
#                                       source  \
# 0                             Facebook posts
# 22   Association of Mature American Citizens
# 49                             The Other 98%
# 68                              Kelly McGinn
# 87                               Viral image
# 106                              Viral image
# 123                                 Bloggers
# 149                           Tucker Carlson
# 171                           Facebook posts
# 191                           Facebook posts
#
#                                                                                                                                link  \
# 0                   /facebook-fact-checks/statements/2019/oct/25/facebook-posts/no-british-parliament-didnt-ban-witchcraft-lipstic/
# 22   /truth-o-meter/statements/2019/oct/22/association-mature-american-citizens/online-ads-claiming-aarp-backed-federal-funding-pl/
# 49                                  /punditfact/statements/2019/oct/14/other-98/theres-no-proof-barr-played-role-shepard-smiths-fo/
# 68                                /virginia/statements/2019/oct/09/kelly-mcginn/kelly-mcginn-invents-position-danica-roem-abortion/
# 87                           /facebook-fact-checks/statements/2019/oct/02/viral-image/photo-philadelphia-musician-not-beto-orourke/
# 106                                  /facebook-fact-checks/statements/2019/sep/26/viral-image/no-woman-isnt-snorting-cocaine-child/
# 123                   /facebook-fact-checks/statements/2019/sep/20/blog-posting/no-evidence-churchill-said-quote-about-diplomacy-b/
# 149                           /punditfact/statements/2019/sep/13/tucker-carlson/tucker-carlson-falsely-claims-john-bolton-was-man-/
# 171                 /facebook-fact-checks/statements/2019/sep/06/facebook-posts/donald-trump-did-not-credit-florida-gov-ron-desant/
# 191                 /facebook-fact-checks/statements/2019/sep/04/facebook-posts/quote-attributed-churchill-having-enemies-original/
#
#            veracity
# 0    Pants on Fire!
# 22            False
# 49            False
# 68            False
# 87   Pants on Fire!
# 106  Pants on Fire!
# 123           False
# 149  Pants on Fire!
# 171  Pants on Fire!
# 191           False

# %% [markdown]
# # Negative Predictive Value: 100%
# ## true negative / (true negative + false negative)

# %%
# Let's see how much data remains with this filtering method, i.e., how many are True
Counter(ver_df.statement.str.match(r"\""))
# Out:
# Counter({False: 4016, True: 3415})

# %%
# verify above results using a different method
Counter(ver_df.statement.str.startswith('"'))
# Out:
# Counter({False: 4016, True: 3415})

# %% [markdown]
# # 3415 rows survive

# %% [markdown]
# # Do other filters give better survival rates?

# %% [markdown]
# # Filter: contains second-hand statement

# %%
ver_df[ver_df.statement.str.contains(r"Says|Quotes|Say|Said|say|saying|said")==True][0:100:10]
# Out:
#                                                                                                                                                                              statement  \
# 0                                     Says that in 1770 "British parliament banned lipstick, saying it had the power to seduce men into marriage, which was classified as witchcraft."
# 26                                                                                                                          Says a photo shows "Kurdish kids" after Turkey’s invasion.
# 54                                                                                                                                            Says Facebook now has a "witch checker."
# 79                                                             Quotes Thomas Jefferson as saying that "freedom is lost gradually from uninterested, uninformed and uninvolved people."
# 107                                                                                   Says Andy Rooney wrote a long commentary defending prayer and Christianity in the United States.
# 132                                                                                                                              Says Ilhan Omar "partied" on the anniversary of 9/11.
# 167  Says after a car accident comedian Kevin Hart has been "paralyzed from the neck down" and his "vocal cords have been paralyzed as well, leaving him with the inability to speak."
# 193                                                                                                               Says the "bones of children" were found on Jeffrey Epstein’s island.
# 222                                                                          Says 194 people were killed in mass shootings in 2018 while undocumented immigrants killed 83,211 people.
# 248  Says CNN President Jeff Zucker ordered employees to downplay Bill Clinton’s relationship with Jeffrey Epstein and make it look like Epstein was "Trump’s partner in all of this."
#
#              source  \
# 0    Facebook posts
# 26      Viral image
# 54   Facebook posts
# 79   Facebook posts
# 107     Viral image
# 132    Donald Trump
# 167  Facebook posts
# 193  Facebook posts
# 222  Facebook posts
# 248  Facebook posts
#
#                                                                                                                 link  \
# 0    /facebook-fact-checks/statements/2019/oct/25/facebook-posts/no-british-parliament-didnt-ban-witchcraft-lipstic/
# 26      /facebook-fact-checks/statements/2019/oct/21/viral-image/these-photos-are-palestinian-and-syrian-children-n/
# 54   /facebook-fact-checks/statements/2019/oct/11/facebook-posts/viral-posts-about-facebook-witch-checker-just-bunc/
# 79   /facebook-fact-checks/statements/2019/oct/04/facebook-posts/jefferson-didnt-say-freedom-lost-gradually-uninter/
# 107     /facebook-fact-checks/statements/2019/sep/26/viral-image/texas-sports-editor-wrote-column-christianity-and-/
# 132           /truth-o-meter/statements/2019/sep/19/donald-trump/trump-retweets-false-claim-ilhan-omar-partied-911-/
# 167  /facebook-fact-checks/statements/2019/sep/09/facebook-posts/no-kevin-hart-wasnt-paralyzed-neck-down-didnt-inju/
# 193  /facebook-fact-checks/statements/2019/sep/04/facebook-posts/no-bones-children-were-not-discovered-jeffrey-epst/
# 222  /facebook-fact-checks/statements/2019/aug/26/facebook-posts/post-comparing-mass-shooting-deaths-homicides-undo/
# 248  /facebook-fact-checks/statements/2019/aug/16/facebook-posts/no-cnn-president-jeff-zucker-didnt-order-employees/
#
#            veracity
# 0    Pants on Fire!
# 26            False
# 54   Pants on Fire!
# 79            False
# 107           False
# 132  Pants on Fire!
# 167           False
# 193           False
# 222           False
# 248  Pants on Fire!

# %% [markdown]
# # Precision: 100%

# %%
ver_df[ver_df.statement.str.contains(r"Says|Quotes|Say|Said|say|saying|said")==False][0:100:10]
# Out:
#                                                                                                                                                                             statement  \
# 3                                                                                                                          "14,000 abandoned wind turbines litter the United States."
# 35                                                                                                                                              "The Kurds are much safer right now."
# 72                                                                              Del. Debra Rodman "opposes adoption as an alternative to abortion in event of unplanned pregnancies."
# 104                                                                                                          The Green New Deal "would put a $600,000 tax burden on every household."
# 148                                                                                                                             The Odessa shooter "had a Beto sticker on his truck."
# 182                                                                         The Amazon rainforest fires are "directly related to trade" tensions between the United States and China.
# 214                                                        "89,000 children were separated from their parents under Obama" and "only 1,900 children have been separated under Trump."
# 240                                                             "Wow, Report Just Out! Google manipulated from 2.6 million to 16 million votes for Hillary Clinton in 2016 Election!"
# 291                                                                                      There are "more gun deaths by far" in the United States than any other country in the world.
# 332  "George Washington, as many don’t know, was not the first President of the United States. The first President of the United States was one John Hanson, and he was a black man."
#
#                           source  \
# 3                    Chain email
# 35                  Donald Trump
# 72             Siobhan Dunnavant
# 104  Republican Party of Florida
# 148                  Viral image
# 182                 John Delaney
# 214               Facebook posts
# 240                 Donald Trump
# 291             Dianne Feinstein
# 332                     Bloggers
#
#                                                                                                                 link  \
# 3                   /missouri/statements/2019/oct/25/chain-email/no-there-arent-14000-abandoned-wind-turbines-litte/
# 35            /truth-o-meter/statements/2019/oct/16/donald-trump/after-attacks-turkey-trump-falsely-claims-kurds-sy/
# 72            /virginia/statements/2019/oct/08/siobhan-dunnavant/dunnavant-falsely-claims-rodman-favors-abortion-ov/
# 104     /florida/statements/2019/sep/27/republican-party-florida/gop-talking-point-green-new-deal-will-cost-every-h/
# 148     /facebook-fact-checks/statements/2019/sep/13/viral-image/no-evidence-odessa-shooter-had-sticker-his-vehicle/
# 182              /truth-o-meter/statements/2019/sep/06/john-delaney/trumps-trade-war-blame-amazon-wildfires-s-reach/
# 214  /facebook-fact-checks/statements/2019/aug/27/facebook-posts/facebook-post-makes-inaccurate-comparison-family-s/
# 240           /truth-o-meter/statements/2019/aug/19/donald-trump/donald-trump-wrong-google-manipulating-election-re/
# 291          /california/statements/2019/aug/06/dianne-feinstein/fact-check-are-there-more-gun-deaths-far-america-a/
# 332    /facebook-fact-checks/statements/2019/jul/25/blog-posting/no-first-american-president-wasnt-black-man-named-/
#
#            veracity
# 3    Pants on Fire!
# 35            False
# 72            False
# 104           False
# 148           False
# 182           False
# 214           False
# 240           False
# 291           False
# 332           False

# %% [markdown]
# # Negative Predictive Value: 100%

# %%
Counter(ver_df.statement.str.contains(r"Says|Quotes|Say|Said|say|saying|said"))
# Out:
# Counter({True: 2165, False: 5266})

# %% [markdown]
# # 5266 rows survive

# %% [markdown]
# # While more rows survive, the quality of the suriving rows is questionable. For example,
#
# ## Del. Debra Rodman "opposes adoption as an alternative to abortion in event of unplanned pregnancies."
#
# # Liars may use distancing language such as "she" and since the above quote was edited to indicate the subject, Del. Debra Rodman, the quality of this falsehood diminishes. This can also be said of 104, 148, etc.

# %% [markdown]
# # We'll use a begins-with-and-ends-with-quotations filter going forward

# %%
quote_df = ver_df[ver_df.statement.str.match(r'\"')==True]
quote_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3415 entries, 3 to 16610
# Data columns (total 4 columns):
# statement    3415 non-null object
# source       3415 non-null object
# link         3415 non-null object
# veracity     3415 non-null object
# dtypes: object(4)
# memory usage: 133.4+ KB

# %%
# remove sentences that don't end with a quotation
quote_df = quote_df[quote_df.statement.str.endswith('"')==True]
quote_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3171 entries, 3 to 16610
# Data columns (total 4 columns):
# statement    3171 non-null object
# source       3171 non-null object
# link         3171 non-null object
# veracity     3171 non-null object
# dtypes: object(4)
# memory usage: 123.9+ KB

# %%
# remove sentences that are several quotes strung together
quote_df = quote_df[quote_df.statement.str.contains(r'\"{1}.+\"{1}.+\"{1}')==False]
quote_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3083 entries, 3 to 16610
# Data columns (total 4 columns):
# statement    3083 non-null object
# source       3083 non-null object
# link         3083 non-null object
# veracity     3083 non-null object
# dtypes: object(4)
# memory usage: 120.4+ KB

# %%
quote_df.veracity.value_counts()
# Out:
# False             1246
# True              1137
# Pants on Fire!     700
# Name: veracity, dtype: int64

# %%
# how many unique sources?
quote_df.describe(include='all')
# Out:
#                                                                       statement  \
# count                                                                      3083
# unique                                                                     3082
# top     "Obama says Iran is a 'tiny' country, 'doesn't pose a serious threat.'"
# freq                                                                          2
#
#           source  \
# count       3083
# unique      1281
# top     Bloggers
# freq         201
#
#                                                                                                 link  \
# count                                                                                           3083
# unique                                                                                          3083
# top     /texas/statements/2010/mar/04/rick-perry/gov-rick-perry-says-congress-hiked-debt-limit-14-t/
# freq                                                                                               1
#
#        veracity
# count      3083
# unique        3
# top       False
# freq       1246

# %%
# top 10 sources
quote_df.source.value_counts()[:10]
# Out:
# Bloggers           201
# Donald Trump       181
# Barack Obama       101
# Hillary Clinton     58
# John McCain         49
# Mitt Romney         42
# Chain email         41
# Viral image         36
# Facebook posts      35
# Rick Perry          28
# Name: source, dtype: int64

# %% [markdown]
# # There is an imbalance in the sources (some appear far too often)
#
# # By examining the source frequency's mean and median, we can determine how many times most sources are quoted to figure out a way to balance the data

# %%
quote_df.source.value_counts().mean()
# Out:
# 2.4067135050741606

# %%
quote_df.source.value_counts().median()
# Out:
# 1.0

# %%
sum(quote_df.source.value_counts() <= 3)
# Out:
# 1165

# %%
quote_df['freq'] = quote_df.groupby('source')['source'].transform('count')

# %%
quote_df[quote_df.freq <= 3].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1455 entries, 18 to 16610
# Data columns (total 5 columns):
# statement    1455 non-null object
# source       1455 non-null object
# link         1455 non-null object
# veracity     1455 non-null object
# freq         1455 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 68.2+ KB

# %% [markdown]
# # New dataframe will only tolerate a single source appearing 3 times

# %%
balanced_df = quote_df[quote_df.freq <= 3]

# %%
# how many unique sources?
balanced_df.describe(include='all')
# Out:
#                                                                                         statement  \
# count                                                                                        1455
# unique                                                                                       1455
# top     "We pay among the highest tolls in the nation for the privilege of crossing that bridge."
# freq                                                                                            1
# mean                                                                                          NaN
# std                                                                                           NaN
# min                                                                                           NaN
# 25%                                                                                           NaN
# 50%                                                                                           NaN
# 75%                                                                                           NaN
# max                                                                                           NaN
#
#                    source  \
# count                1455
# unique               1165
# top     Dennis Richardson
# freq                    3
# mean                  NaN
# std                   NaN
# min                   NaN
# 25%                   NaN
# 50%                   NaN
# 75%                   NaN
# max                   NaN
#
#                                                                                                link  \
# count                                                                                          1455
# unique                                                                                         1455
# top     /texas/statements/2014/mar/20/jim-moore/sen-ted-cruz-has-been-iowa-four-times-his-tenure-r/
# freq                                                                                              1
# mean                                                                                            NaN
# std                                                                                             NaN
# min                                                                                             NaN
# 25%                                                                                             NaN
# 50%                                                                                             NaN
# 75%                                                                                             NaN
# max                                                                                             NaN
#
#        veracity         freq
# count      1455  1455.000000
# unique        3          NaN
# top       False          NaN
# freq        576          NaN
# mean        NaN     1.471478
# std         NaN     0.684153
# min         NaN     1.000000
# 25%         NaN     1.000000
# 50%         NaN     1.000000
# 75%         NaN     2.000000
# max         NaN     3.000000

# %%
balanced_df.veracity.value_counts()
# Out:
# False             576
# True              571
# Pants on Fire!    308
# Name: veracity, dtype: int64

# %%
# top 10 sources
balanced_df.source.value_counts()[:10]
# Out:
# Dennis Richardson     3
# Richard Durbin        3
# Marcia Fudge          3
# Pam Bondi             3
# Tim Ryan              3
# Bill O'Reilly         3
# Lamar Alexander       3
# Bill Nelson           3
# Randy Forbes          3
# Kirsten Gillibrand    3
# Name: source, dtype: int64

# %% [markdown]
# # 1455 balanced rows survived

# %%
balanced_df[:100:5]
# Out:
#                                                                                                                                                                               statement  \
# 18                                                                                        "The vast majority of Wisconsin students cannot even read, write, or do math at grade level."
# 61                                                                         "About 95 percent of America’s production of ethylene is produced on the Gulf Coast in Texas and Louisiana."
# 91                                                                                                                         "More than half of death row prisoners are people of color."
# 208                                                                                                      "1 out of every 4 car accidents in the U.S. is caused by texting and driving."
# 295                                                                                                                                                  "Less mass shootings under Trump!"
# 397                                                                                                            "Texas medical professional: Migrants quarantined with UNKNOWN disease."
# 476                                                                                                                            "Every day on average 500 people die from gun violence."
# 543                                                                                                                                       "I actually in 2005 ran on Medicare for all."
# 613                                                              "We suspended the (Foxconn) work around October, November last year because the weather there was snowy and icy cold."
# 651                                                                                                                          "Every county in the state of Texas has a veterans court."
# 668                                                                                                        "The White House fully cooperated with the Special Counsel’s investigation."
# 702                                                                                                              "North Carolina last year was second in the nation in overdose deaths"
# 755                                       "Women in Virginia have been incarcerated at an increasingly high rate. It’s around (a) 300 percent increase in the past four or five years."
# 801                                                                 "Over the last eight years, we’ve shown that even though we’ve cut taxes by $8 billion, revenues continue to grow."
# 858                     "Since 2011, the gap in high school graduation rates between African-American students and all students has been cut in half, from 6.4 percent to 3.1 percent."
# 974                                          "Racist picture of Democrat North Carolina Governor Roy Cooper emerges just days after he called on Ralph Northam to resign - DAILY MAIL."
# 1042  "Nancy Pelosi's bill for alcohol on her flights from Washington to San Fran every week? We pay for it. 1000 dollars. On average 52,000 Bucks, a year for BOOZE. Tax payer money."
# 1120                                                                                                                                  "Democrats flip flop on pre-existing conditions."
# 1189                  "We are watching, you know, millions of illegal immigrants cross our borders, and many of them voting in the past election that's what, just a couple weeks ago."
# 1257                                                                                                       "Do you know that New York State pays out way more than they ever get back?"
#
#                    source  \
# 18      Jeremy Thiesfeldt
# 61         David McKinley
# 91             Gwen Moore
# 208            Tony Evers
# 295            Ron Tusler
# 397   Big League Politics
# 476            Ilhan Omar
# 543    Kirsten Gillibrand
# 613             Terry Gou
# 651         Dave Griffith
# 668          William Barr
# 702           Harry Brown
# 755             Kaye Kory
# 801           John Nygren
# 858           Phil Berger
# 974            Jacob Wohl
# 1042        Chuck Woolery
# 1120      Alberta Darling
# 1189            Lou Dobbs
# 1257      Nathan McMurray
#
#                                                                                                                       link  \
# 18                 /wisconsin/statements/2019/oct/23/jeremy-thiesfeldt/no-vast-majority-wisconsin-students-are-not-below-/
# 61                              /west-virginia/statements/2019/oct/10/david-mckinley/fact-checking-ethylene-production-us/
# 91                        /wisconsin/statements/2019/oct/01/gwen-moore/state-lawmaker-hits-target-claim-racial-background/
# 208                                     /wisconsin/statements/2019/aug/28/tony-evers/evers-wrong-texting-and-driving-stat/
# 295                       /wisconsin/statements/2019/aug/06/ron-tusler/pants-fire-state-rep-claims-mass-shootings-are-dow/
# 397   /facebook-fact-checks/statements/2019/jul/03/big-league-politics/no-migrants-arent-being-quarantined-unknown-diseas/
# 476                   /truth-o-meter/statements/2019/jun/12/ilhan-omar/rep-ilhan-omars-claim-high-there-arent-500-gun-dea/
# 543                      /new-york/statements/2019/may/22/kirsten-gillibrand/gillibrand-points-early-support-medicare-all/
# 613                        /wisconsin/statements/2019/may/02/terry-gou/foxconn-chairman-terry-gou-says-extreme-weather-su/
# 651                     /missouri/statements/2019/apr/25/dave-griffith/does-texas-have-veterans-treatment-court-each-coun/
# 668                 /truth-o-meter/statements/2019/apr/22/william-barr/did-trump-fully-cooperate-mueller-investigation-no/
# 702                    /north-carolina/statements/2019/apr/11/harry-brown/nc-doesnt-have-second-most-drug-overdose-deaths/
# 755                         /virginia/statements/2019/apr/02/kaye-kory/del-kaye-kory-way-about-surge-women-prisoners-virg/
# 801                      /wisconsin/statements/2019/mar/21/john-nygren/john-nygren-says-wisconsin-republicans-have-cut-ta/
# 858                 /north-carolina/statements/2019/mar/07/phil-berger/berger-correct-high-school-graduation-rates-africa/
# 974                  /north-carolina/statements/2019/feb/09/jacob-wohl/trump-supporter-spreads-fake-news-about-nc-governo/
# 1042                         /punditfact/statements/2019/jan/22/chuck-woolery/no-evidence-back-claim-about-pelosi-bar-tab/
# 1120                 /wisconsin/statements/2018/dec/18/alberta-darling/did-wisconsin-democrats-flip-flop-pre-existing-con/
# 1189                      /punditfact/statements/2018/nov/16/lou-dobbs/no-evidence-many-illegal-immigrants-voted-midterm-/
# 1257                               /new-york/statements/2018/nov/02/nathan-mcmurray/new-york-giver-state-federal-treasury/
#
#             veracity  freq
# 18             False     1
# 61              True     1
# 91              True     3
# 208            False     2
# 295   Pants on Fire!     1
# 397            False     1
# 476            False     1
# 543             True     3
# 613            False     1
# 651            False     1
# 668            False     1
# 702            False     1
# 755            False     1
# 801             True     1
# 858             True     1
# 974   Pants on Fire!     2
# 1042  Pants on Fire!     1
# 1120           False     3
# 1189  Pants on Fire!     1
# 1257            True     1

# %% [markdown]
# # Verify the dates of the data

# %%
# extracting the date from the link column
# r() = first group to extract; you can use multiple ()
# ?P<column_name> = column name for convenience
# \d = digit
# {n} = number of digits to include
# . = wildcard
# + = greedy search
# ? = but not too greedy
balanced_df["date"] = balanced_df.link.str.extract(r'(\d{4}/.+?\d{2})')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
balanced_df
# Out:
#                                                                                                                                                                                                      statement  \
# 18                                                                                                               "The vast majority of Wisconsin students cannot even read, write, or do math at grade level."
# 21     "President Trump has sent 14,000 American troops to the (Middle East) region since May. So he can't tell his political rallies that he's getting troops out of endless wars when he's sending 14 tim...
# 27                                                                                                                                           "To be clear, I’m not talking about confiscating anybody’s guns."
# 30                                                                                                       "When my father became commander in chief of this country, we got out of all international business."
# 42                                                                                                        "Ohio, Michigan, and Pennsylvania actually in the latest jobs data have lost jobs, not gained them."
# 61                                                                                                "About 95 percent of America’s production of ethylene is produced on the Gulf Coast in Texas and Louisiana."
# 64                                                                             "Meth production in MO has cratered over last decade. MO Hwy Patrol reported 1,326 meth lab seizures in 2006, only 50 in 2018."
# 73                                                                                                                                                       "We have not spoken directly with the whistleblower."
# 76                                                                                          "50% of the DUIs on Interstate 35 are from illegals. Ninety percent of the 50% have absolutely no identification."
# 85                                                              "If the impeachment reaches the house and passes to the senate and isn’t passed the first term is nullified and Trump can run two more terms."
# 91                                                                                                                                                "More than half of death row prisoners are people of color."
# 168                                                                                                                        "There are 390 million guns out on the streets of a country of 329 million people."
# 179                                                                                                                                                         "Gov. Evers asked the director of WEDC to stay on"
# 180                                                                                                                                   "America has more governors who’ve worn blackface than black governors."
# 186                                                         "The last time people (created a Hollywood blacklist), people ended up killing themselves … They were accused, and they lost their right to work."
# 208                                                                                                                             "1 out of every 4 car accidents in the U.S. is caused by texting and driving."
# 220                                 "Trump is as destructive a person in this century as Hitler, Stalin, and Mao were in the last century. He may be responsible for many more million deaths than they were."
# 226                                                                                                                                      "Elected officials draw (legislative redistricting) maps. That’s it."
# 265                                                                                                                       "More Americans are uninsured today than when (President Donald) Trump took office."
# 290    "What Congress is considering would cut money that vulnerable patients rely on the most. That means seniors, children and Americans who rely on Medicaid would be hurt. … Tell Congress we can end s...
# 295                                                                                                                                                                         "Less mass shootings under Trump!"
# 302                                                                                                                     "Elijah Cummings’ house was broken into after Trump publicly attacked him on Twitter."
# 339                                                                                            "How many people have with a concealed carry permit have committed a crime in Virginia? ...The answer is zero."
# 348                                                                                                    "Indiana actually has a higher gas tax than Illinois does even with the increase in (Illinois’) taxes."
# 370           "A study was done, a post-mortem, so a retrospective study done, looking at autopsies and drug levels, what drugs were in the blood of veterans that committed suicide, and 70 percent had THC."
# 397                                                                                                                                   "Texas medical professional: Migrants quarantined with UNKNOWN disease."
# 409                                                                                                           "The typical black family in this country has one-tenth the wealth of the typical white family."
# 424    "If you go to every hospital in this country and you ask them one question, which is, ‘How would it have been for you last year if every one of your bills were paid at the Medicare rate?’ Every si...
# 468                                                                                           "Most research shows that (UW salaries) are a little behind, and (in) some areas we're behind more than others."
# 471                                                                                                                                                    "Richard Nixon was the last president to be impeached."
# ...                                                                                                                                                                                                        ...
# 15815                                                                                                                           "Barack Obama has consistently voted against tougher penalties for criminals."
# 15876                                                                                                                            "Palin (proposed) a $150 bounty for the severed foreleg of each killed wolf."
# 15977                                                                                                             "Less than four cents of every health care dollar is spent on prevention and public health."
# 15986                                                                             "We spend more on health care than any other country, but we're ranked 47th in life expectancy and 43rd in child mortality."
# 16037                                                                                                                          "McCain got more money from Airbus' U.S. executives than any other politician."
# 16038                                                                                                                                      "Sen. McCain would occupy Iraq indefinitely, against their wishes."
# 16080  "The legislation ... that Senator McCain supports would provide the authority for the federal government to surveille American citizens in their own country without any suspicion whatsoever that t...
# 16085                                                                            "He won't even support his colleague's ... motion to censure the Bush administration for systemic repeated illegal wiretaps."
# 16119                                                                                                                                                                           "Fidel Castro endorses Obama."
# 16179                                                                "As a state senator, he (Obama) even refused to support a measure to stop sex businesses from opening near schools or places of worship!"
# 16201                                                           "Among his (Obama's) pet projects is a bill ... which would commit the U.S. to spending 0.7 percent of gross national product on foreign aid."
# 16222                                                                                                                                                                "I am a candidate. I have not withdrawn."
# 16233                                                                                                               "You don't even have to go outside Obama's campaign to find advisers who are anti-Israel."
# 16242                                                                                                                "John McCain says it's okay with him if the U.S. spends the next thousand years in Iraq."
# 16293                                                                                                                                    "(John McCain) was even mentioned as a running mate with John Kerry."
# 16393                                                                                "And, you know, our first president and our first commander in chief prayed every day. He had a field manual of prayers."
# 16401                                                                               "We've got some 37-million of our fellow citizens who are living in poverty; about 12-million or 13-million are children."
# 16420                     "I spend a lot of time in Iowa, and believe it or not, in Ottumwa, Iowa, this is the heartland, the newspaper, the regular newspaper for Ottumwa, Iowa, is (a) bilingual newspaper."
# 16445                                                                                                                  "Congress' approval rating is 11 percent. You know who's higher? Dick Cheney and HMOs."
# 16446                                                                                  "Three out of the 18 benchmarks of the (GAO) have been fulfilled. Even among Republican math, that is a failing grade."
# 16473                                                                                                                           "Dodd brought both parties together to pass the Family and Medical Leave Act."
# 16504                                                                               "This (SCHIP) is socialized medicine. It is going to go to families that make $60,000 a year. Those aren't poor children."
# 16552                                                                                                                                                                                "I'm pro-life. He's not."
# 16557                                                                            "Iowa, for good reason, for constitutional reasons, for reasons related to the Lord, should be the first caucus and primary."
# 16576                                                                                                                                    "Currently, we're at 36 percent of our children born out of wedlock."
# 16583                                                           "In 1972, we had a 179,000 human beings in jail in this country. Today, it's 2.3-million, and 70 percent of them are black, African-American."
# 16602                                                                                                                                     "I'm for a three-state political solution in Iraq. (Romney) is not."
# 16606                                  "For every single scientist that tells you (global warming is) happening and that it's our fault...I can stack up another group of reports that say just the opposite."
# 16609                         "Tommy Thompson is the father of welfare reform, creating the groundbreaking Wisconsin Works program in Wisconsin that became the model for national and international reforms."
# 16610  "Tommy Thompson created the first school choice program in the nation, giving thousands of Milwaukee students the choice of where they go to school – no matter where they live or how much money th...
#
#                                        source  \
# 18                          Jeremy Thiesfeldt
# 21                               Brett McGurk
# 27                              Beto O'Rourke
# 30                                 Eric Trump
# 42                              Julián Castro
# 61                             David McKinley
# 64                                Josh Hawley
# 73                                Adam Schiff
# 76                             Roger Williams
# 85                                 Kaya Jones
# 91                                 Gwen Moore
# 168                             Beto O'Rourke
# 179                           Alberta Darling
# 180                          Samuel Sinyangwe
# 186                           Whoopi Goldberg
# 208                                Tony Evers
# 220                             Allen Frances
# 226                              Adam Jarchow
# 265                             Tammy Baldwin
# 290              Physicians for Fair Coverage
# 295                                Ron Tusler
# 302                           Chelsea Handler
# 339                              Bill Stanley
# 348                            Susana Mendoza
# 370                            Donna Campbell
# 397                       Big League Politics
# 409                          Ta-Nehisi Coates
# 424                              John Delaney
# 468                                 Ray Cross
# 471                              Jimmy Kimmel
# ...                                       ...
# 15815             Republican Party of Florida
# 15876       Defenders of Wildlife Action Fund
# 15977           Democratic National Committee
# 15986           Democratic National Committee
# 16037                    Campaign Money Watch
# 16038                            VoteVets.org
# 16080                                Bob Barr
# 16085                             Ralph Nader
# 16119             Republican Party of Florida
# 16179              Focus on the Family Action
# 16201              Focus on the Family Action
# 16222                             Mike Gravel
# 16233              Tennessee Republican Party
# 16242                            VoteVets.org
# 16293  Citizens United Political Victory Fund
# 16393                           Duncan Hunter
# 16401                              Chris Dodd
# 16420                            Tom Tancredo
# 16445                         Bill Richardson
# 16446                         Bill Richardson
# 16473                              Chris Dodd
# 16504                           Duncan Hunter
# 16552                           Sam Brownback
# 16557                         Bill Richardson
# 16576                           Sam Brownback
# 16583                             Mike Gravel
# 16602                           Sam Brownback
# 16606                            Tom Tancredo
# 16609                          Tommy Thompson
# 16610                          Tommy Thompson
#
#                                                                                                                           link  \
# 18                     /wisconsin/statements/2019/oct/23/jeremy-thiesfeldt/no-vast-majority-wisconsin-students-are-not-below-/
# 21                         /punditfact/statements/2019/oct/22/brett-mcgurk/mcgurk-right-trump-has-sent-14000-troops-middle-ea/
# 27                      /truth-o-meter/statements/2019/oct/21/beto-orourke/despite-his-claim-presidential-candidate-beto-orou/
# 30                        /truth-o-meter/statements/2019/oct/18/eric-trump/eric-trumps-false-claim-trump-family-got-out-all-i/
# 42                     /truth-o-meter/statements/2019/oct/16/julian-castro/julian-castro-wrong-about-job-losses-ohio-michigan/
# 61                                  /west-virginia/statements/2019/oct/10/david-mckinley/fact-checking-ethylene-production-us/
# 64                            /missouri/statements/2019/oct/10/josh-hawley/missouri-meth-use-hawley-right-lab-seizures-have-d/
# 73                       /truth-o-meter/statements/2019/oct/04/adam-schiff/adam-schiffs-false-claim-we-have-not-spoken-direct/
# 76                            /texas/statements/2019/oct/04/roger-williams/are-half-those-arrested-dwis-i-35-unauthorized-imm/
# 85                             /punditfact/statements/2019/oct/02/kaya-jones/donald-trump-third-term-failed-impeachment-would/
# 91                            /wisconsin/statements/2019/oct/01/gwen-moore/state-lawmaker-hits-target-claim-racial-background/
# 168                                        /texas/statements/2019/sep/09/beto-orourke/how-many-guns-are-streets-united-states/
# 179                      /wisconsin/statements/2019/sep/06/alberta-darling/darling-whiffs-claim-about-evers-and-state-jobs-ag/
# 180                    /punditfact/statements/2019/sep/06/samuel-sinyangwe/its-true-there-are-more-governors-who-have-worn-bl/
# 186                     /punditfact/statements/2019/sep/05/whoopi-goldberg/whoopi-goldberg-warned-about-another-hollywood-bla/
# 208                                         /wisconsin/statements/2019/aug/28/tony-evers/evers-wrong-texting-and-driving-stat/
# 220                       /punditfact/statements/2019/aug/26/allen-frances/pants-fire-claim-donald-trump-has-much-blood-his-h/
# 226                         /wisconsin/statements/2019/aug/23/adam-jarchow/former-wisconsin-rep-misses-mark-redistricting-cla/
# 265                        /wisconsin/statements/2019/aug/13/tammy-baldwin/us-sen-baldwin-right-more-americans-are-without-he/
# 290          /health-check/statements/2019/aug/07/physicians-fair-coverage/doctors-argue-plans-remedy-surprise-medical-bills-/
# 295                           /wisconsin/statements/2019/aug/06/ron-tusler/pants-fire-state-rep-claims-mass-shootings-are-dow/
# 302                     /punditfact/statements/2019/aug/02/chelsea-handler/chelsea-handler-blames-trumps-tweets-break-cumming/
# 339                          /virginia/statements/2019/jul/24/bill-stanley/theres-no-proof-bill-stanleys-claim-about-va-conce/
# 348                        /illinois/statements/2019/jul/21/susana-mendoza/mendozas-comparison-indiana-and-illinois-gasoline-/
# 370                           /texas/statements/2019/jul/15/donna-campbell/did-study-show-70-veterans-who-committed-suicide-h/
# 397       /facebook-fact-checks/statements/2019/jul/03/big-league-politics/no-migrants-arent-being-quarantined-unknown-diseas/
# 409                    /punditfact/statements/2019/jul/01/ta-nehisi-coates/seeking-reparations-ta-nehisi-coates-says-typical-/
# 424                      /health-check/statements/2019/jun/27/john-delaney/delaneys-debate-claim-medicare-all-will-shutter-ho/
# 468                            /wisconsin/statements/2019/jun/14/ray-cross/uw-system-president-hits-pay-dirt-university-pay-g/
# 471                        /punditfact/statements/2019/jun/13/jimmy-kimmel/no-nixon-was-never-officially-impeached-he-resigne/
# ...                                                                                                                        ...
# 15815                                    /truth-o-meter/statements/2008/oct/27/republican-party-florida/felony-cherry-picking/
# 15876     /truth-o-meter/statements/2008/oct/01/defenders-wildlife-action-fund-defenders-wildlife-/palin-endorsed-wolf-bounty/
# 15977                     /truth-o-meter/statements/2008/aug/26/democratic-national-committee/yes-only-an-ounce-on-prevention/
# 15986  /truth-o-meter/statements/2008/aug/25/democratic-national-committee/us-spends-more-on-health-care-not-necessarily-heal/
# 16037           /truth-o-meter/statements/2008/jul/31/campaign-money-watch/mccain-campaign-bouyed-by-airbus-execs-and-lobbyis/
# 16038                             /truth-o-meter/statements/2008/jul/30/votevetsorg/no-fresh-evidence-of-what-mccain-would-do/
# 16080                              /truth-o-meter/statements/2008/jul/02/bob-barr/while-on-big-brother-watch-barr-hits-mccain/
# 16085                                   /truth-o-meter/statements/2008/jun/30/ralph-nader/obama-hasnt-backed-censure-for-bush/
# 16119                            /truth-o-meter/statements/2008/jun/05/republican-party-florida/castro-not-stumping-for-obama/
# 16179                           /truth-o-meter/statements/2008/apr/23/focus-family-action/he-wanted-local-officials-to-decide/
# 16201                     /truth-o-meter/statements/2008/apr/15/focus-family-action/the-bill-has-no-such-spending-requirement/
# 16222                                                       /truth-o-meter/statements/2008/mar/26/mike-gravel/hes-in-the-race/
# 16233                      /truth-o-meter/statements/2008/mar/14/tennessee-republican-party/anti-israel-not-even-key-advisers/
# 16242                                        /truth-o-meter/statements/2008/mar/05/votevetsorg/a-fair-summary-of-what-he-said/
# 16293                           /truth-o-meter/statements/2008/feb/04/citizens-united-political-victory-fund/thats-the-ticket/
# 16393                                      /truth-o-meter/statements/2007/dec/18/duncan-hunter/hunter-perpetuates-common-myth/
# 16401                                              /truth-o-meter/statements/2007/dec/13/chris-dodd/poverty-numbers-are-right/
# 16420                                   /truth-o-meter/statements/2007/nov/29/tom-tancredo/what-about-the-daily-english-paper/
# 16445                                     /truth-o-meter/statements/2007/nov/15/bill-richardson/congress-and-cheney-beat-hmos/
# 16446                                                   /truth-o-meter/statements/2007/nov/15/bill-richardson/yep-3-out-of-18/
# 16473                                       /truth-o-meter/statements/2007/oct/30/chris-dodd/dodd-was-bulldog-in-passing-bill/
# 16504                                     /truth-o-meter/statements/2007/oct/15/duncan-hunter/hunter-schip-estimate-on-target/
# 16552                                         /truth-o-meter/statements/2007/sep/12/sam-brownback/romney-now-opposes-abortion/
# 16557                           /truth-o-meter/statements/2007/sep/10/bill-richardson/richardson-re-writes-bible-constitution/
# 16576                                            /truth-o-meter/statements/2007/sep/03/sam-brownback/hes-got-the-right-number/
# 16583                                     /truth-o-meter/statements/2007/aug/30/mike-gravel/hes-off-way-off-on-whos-in-prison/
# 16602                                  /truth-o-meter/statements/2007/jul/10/sam-brownback/a-fair-account-of-romneys-position/
# 16606                             /truth-o-meter/statements/2007/jun/12/tom-tancredo/most-scientists-say-humans-cause-warming/
# 16609                            /truth-o-meter/statements/2007/jun/01/tommy-thompson/thompson-was-a-leader-in-welfare-reform/
# 16610                                      /truth-o-meter/statements/2007/may/02/tommy-thompson/he-was-credited-as-a-tinkerer/
#
#              veracity  freq         date
# 18              False     1  2019/oct/23
# 21               True     1  2019/oct/22
# 27              False     3  2019/oct/21
# 30     Pants on Fire!     1  2019/oct/18
# 42              False     3  2019/oct/16
# 61               True     1  2019/oct/10
# 64               True     1  2019/oct/10
# 73              False     2  2019/oct/04
# 76     Pants on Fire!     1  2019/oct/04
# 85     Pants on Fire!     1  2019/oct/02
# 91               True     3  2019/oct/01
# 168              True     3  2019/sep/09
# 179             False     3  2019/sep/06
# 180              True     1  2019/sep/06
# 186              True     1  2019/sep/05
# 208             False     2  2019/aug/28
# 220    Pants on Fire!     1  2019/aug/26
# 226             False     1  2019/aug/23
# 265              True     2  2019/aug/13
# 290             False     1  2019/aug/07
# 295    Pants on Fire!     1  2019/aug/06
# 302             False     1  2019/aug/02
# 339             False     1  2019/jul/24
# 348             False     1  2019/jul/21
# 370    Pants on Fire!     1  2019/jul/15
# 397             False     1  2019/jul/03
# 409              True     1  2019/jul/01
# 424             False     1  2019/jun/27
# 468              True     1  2019/jun/14
# 471             False     1  2019/jun/13
# ...               ...   ...          ...
# 15815           False     3  2008/oct/27
# 15876            True     1  2008/oct/01
# 15977            True     2  2008/aug/26
# 15986            True     2  2008/aug/25
# 16037            True     1  2008/jul/31
# 16038           False     2  2008/jul/30
# 16080            True     1  2008/jul/02
# 16085            True     1  2008/jun/30
# 16119  Pants on Fire!     3  2008/jun/05
# 16179            True     2  2008/apr/23
# 16201           False     2  2008/apr/15
# 16222            True     2  2008/mar/26
# 16233           False     1  2008/mar/14
# 16242            True     2  2008/mar/05
# 16293            True     1  2008/feb/04
# 16393           False     2  2007/dec/18
# 16401            True     2  2007/dec/13
# 16420           False     2  2007/nov/29
# 16445           False     3  2007/nov/15
# 16446            True     3  2007/nov/15
# 16473            True     2  2007/oct/30
# 16504            True     2  2007/oct/15
# 16552           False     3  2007/sep/12
# 16557  Pants on Fire!     3  2007/sep/10
# 16576            True     3  2007/sep/03
# 16583  Pants on Fire!     2  2007/aug/30
# 16602            True     3  2007/jul/10
# 16606           False     2  2007/jun/12
# 16609            True     3  2007/jun/01
# 16610            True     3  2007/may/02
#
# [1455 rows x 6 columns]

# %%
# change the date column to a datetime column for convenience
balanced_df.date = pd.to_datetime(balanced_df.date,infer_datetime_format=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
balanced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1455 entries, 18 to 16610
# Data columns (total 6 columns):
# statement    1455 non-null object
# source       1455 non-null object
# link         1455 non-null object
# veracity     1455 non-null object
# freq         1455 non-null int64
# date         1455 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 79.6+ KB

# %%
balanced_df.head(2)
# Out:
#                                                                                                                                                                                                   statement  \
# 18                                                                                                            "The vast majority of Wisconsin students cannot even read, write, or do math at grade level."
# 21  "President Trump has sent 14,000 American troops to the (Middle East) region since May. So he can't tell his political rallies that he's getting troops out of endless wars when he's sending 14 tim...
#
#                source  \
# 18  Jeremy Thiesfeldt
# 21       Brett McGurk
#
#                                                                                                        link  \
# 18  /wisconsin/statements/2019/oct/23/jeremy-thiesfeldt/no-vast-majority-wisconsin-students-are-not-below-/
# 21      /punditfact/statements/2019/oct/22/brett-mcgurk/mcgurk-right-trump-has-sent-14000-troops-middle-ea/
#
#    veracity  freq       date
# 18    False     1 2019-10-23
# 21     True     1 2019-10-22

# %%
#by year
ax = balanced_df.groupby(balanced_df.date.dt.year).count().plot(kind="bar")
ax.legend_ = None
plt.title("Distribution by Year")
plt.show()

# %%
#by month
ax = balanced_df.groupby(balanced_df.date.dt.month).count().plot(kind="bar")
ax.legend_ = None
plt.title("Distribution by Month")
plt.show()

# %% [markdown]
# # The quality and balance of the data has improved

# %%
cleaned_df = balanced_df[["date","source","freq","statement","veracity"]]

# %%
cleaned_df
# Out:
#             date                                  source  freq  \
# 18    2019-10-23                       Jeremy Thiesfeldt     1
# 21    2019-10-22                            Brett McGurk     1
# 27    2019-10-21                           Beto O'Rourke     3
# 30    2019-10-18                              Eric Trump     1
# 42    2019-10-16                           Julián Castro     3
# 61    2019-10-10                          David McKinley     1
# 64    2019-10-10                             Josh Hawley     1
# 73    2019-10-04                             Adam Schiff     2
# 76    2019-10-04                          Roger Williams     1
# 85    2019-10-02                              Kaya Jones     1
# 91    2019-10-01                              Gwen Moore     3
# 168   2019-09-09                           Beto O'Rourke     3
# 179   2019-09-06                         Alberta Darling     3
# 180   2019-09-06                        Samuel Sinyangwe     1
# 186   2019-09-05                         Whoopi Goldberg     1
# 208   2019-08-28                              Tony Evers     2
# 220   2019-08-26                           Allen Frances     1
# 226   2019-08-23                            Adam Jarchow     1
# 265   2019-08-13                           Tammy Baldwin     2
# 290   2019-08-07            Physicians for Fair Coverage     1
# 295   2019-08-06                              Ron Tusler     1
# 302   2019-08-02                         Chelsea Handler     1
# 339   2019-07-24                            Bill Stanley     1
# 348   2019-07-21                          Susana Mendoza     1
# 370   2019-07-15                          Donna Campbell     1
# 397   2019-07-03                     Big League Politics     1
# 409   2019-07-01                        Ta-Nehisi Coates     1
# 424   2019-06-27                            John Delaney     1
# 468   2019-06-14                               Ray Cross     1
# 471   2019-06-13                            Jimmy Kimmel     1
# ...          ...                                     ...   ...
# 15815 2008-10-27             Republican Party of Florida     3
# 15876 2008-10-01       Defenders of Wildlife Action Fund     1
# 15977 2008-08-26           Democratic National Committee     2
# 15986 2008-08-25           Democratic National Committee     2
# 16037 2008-07-31                    Campaign Money Watch     1
# 16038 2008-07-30                            VoteVets.org     2
# 16080 2008-07-02                                Bob Barr     1
# 16085 2008-06-30                             Ralph Nader     1
# 16119 2008-06-05             Republican Party of Florida     3
# 16179 2008-04-23              Focus on the Family Action     2
# 16201 2008-04-15              Focus on the Family Action     2
# 16222 2008-03-26                             Mike Gravel     2
# 16233 2008-03-14              Tennessee Republican Party     1
# 16242 2008-03-05                            VoteVets.org     2
# 16293 2008-02-04  Citizens United Political Victory Fund     1
# 16393 2007-12-18                           Duncan Hunter     2
# 16401 2007-12-13                              Chris Dodd     2
# 16420 2007-11-29                            Tom Tancredo     2
# 16445 2007-11-15                         Bill Richardson     3
# 16446 2007-11-15                         Bill Richardson     3
# 16473 2007-10-30                              Chris Dodd     2
# 16504 2007-10-15                           Duncan Hunter     2
# 16552 2007-09-12                           Sam Brownback     3
# 16557 2007-09-10                         Bill Richardson     3
# 16576 2007-09-03                           Sam Brownback     3
# 16583 2007-08-30                             Mike Gravel     2
# 16602 2007-07-10                           Sam Brownback     3
# 16606 2007-06-12                            Tom Tancredo     2
# 16609 2007-06-01                          Tommy Thompson     3
# 16610 2007-05-02                          Tommy Thompson     3
#
#                                                                                                                                                                                                      statement  \
# 18                                                                                                               "The vast majority of Wisconsin students cannot even read, write, or do math at grade level."
# 21     "President Trump has sent 14,000 American troops to the (Middle East) region since May. So he can't tell his political rallies that he's getting troops out of endless wars when he's sending 14 tim...
# 27                                                                                                                                           "To be clear, I’m not talking about confiscating anybody’s guns."
# 30                                                                                                       "When my father became commander in chief of this country, we got out of all international business."
# 42                                                                                                        "Ohio, Michigan, and Pennsylvania actually in the latest jobs data have lost jobs, not gained them."
# 61                                                                                                "About 95 percent of America’s production of ethylene is produced on the Gulf Coast in Texas and Louisiana."
# 64                                                                             "Meth production in MO has cratered over last decade. MO Hwy Patrol reported 1,326 meth lab seizures in 2006, only 50 in 2018."
# 73                                                                                                                                                       "We have not spoken directly with the whistleblower."
# 76                                                                                          "50% of the DUIs on Interstate 35 are from illegals. Ninety percent of the 50% have absolutely no identification."
# 85                                                              "If the impeachment reaches the house and passes to the senate and isn’t passed the first term is nullified and Trump can run two more terms."
# 91                                                                                                                                                "More than half of death row prisoners are people of color."
# 168                                                                                                                        "There are 390 million guns out on the streets of a country of 329 million people."
# 179                                                                                                                                                         "Gov. Evers asked the director of WEDC to stay on"
# 180                                                                                                                                   "America has more governors who’ve worn blackface than black governors."
# 186                                                         "The last time people (created a Hollywood blacklist), people ended up killing themselves … They were accused, and they lost their right to work."
# 208                                                                                                                             "1 out of every 4 car accidents in the U.S. is caused by texting and driving."
# 220                                 "Trump is as destructive a person in this century as Hitler, Stalin, and Mao were in the last century. He may be responsible for many more million deaths than they were."
# 226                                                                                                                                      "Elected officials draw (legislative redistricting) maps. That’s it."
# 265                                                                                                                       "More Americans are uninsured today than when (President Donald) Trump took office."
# 290    "What Congress is considering would cut money that vulnerable patients rely on the most. That means seniors, children and Americans who rely on Medicaid would be hurt. … Tell Congress we can end s...
# 295                                                                                                                                                                         "Less mass shootings under Trump!"
# 302                                                                                                                     "Elijah Cummings’ house was broken into after Trump publicly attacked him on Twitter."
# 339                                                                                            "How many people have with a concealed carry permit have committed a crime in Virginia? ...The answer is zero."
# 348                                                                                                    "Indiana actually has a higher gas tax than Illinois does even with the increase in (Illinois’) taxes."
# 370           "A study was done, a post-mortem, so a retrospective study done, looking at autopsies and drug levels, what drugs were in the blood of veterans that committed suicide, and 70 percent had THC."
# 397                                                                                                                                   "Texas medical professional: Migrants quarantined with UNKNOWN disease."
# 409                                                                                                           "The typical black family in this country has one-tenth the wealth of the typical white family."
# 424    "If you go to every hospital in this country and you ask them one question, which is, ‘How would it have been for you last year if every one of your bills were paid at the Medicare rate?’ Every si...
# 468                                                                                           "Most research shows that (UW salaries) are a little behind, and (in) some areas we're behind more than others."
# 471                                                                                                                                                    "Richard Nixon was the last president to be impeached."
# ...                                                                                                                                                                                                        ...
# 15815                                                                                                                           "Barack Obama has consistently voted against tougher penalties for criminals."
# 15876                                                                                                                            "Palin (proposed) a $150 bounty for the severed foreleg of each killed wolf."
# 15977                                                                                                             "Less than four cents of every health care dollar is spent on prevention and public health."
# 15986                                                                             "We spend more on health care than any other country, but we're ranked 47th in life expectancy and 43rd in child mortality."
# 16037                                                                                                                          "McCain got more money from Airbus' U.S. executives than any other politician."
# 16038                                                                                                                                      "Sen. McCain would occupy Iraq indefinitely, against their wishes."
# 16080  "The legislation ... that Senator McCain supports would provide the authority for the federal government to surveille American citizens in their own country without any suspicion whatsoever that t...
# 16085                                                                            "He won't even support his colleague's ... motion to censure the Bush administration for systemic repeated illegal wiretaps."
# 16119                                                                                                                                                                           "Fidel Castro endorses Obama."
# 16179                                                                "As a state senator, he (Obama) even refused to support a measure to stop sex businesses from opening near schools or places of worship!"
# 16201                                                           "Among his (Obama's) pet projects is a bill ... which would commit the U.S. to spending 0.7 percent of gross national product on foreign aid."
# 16222                                                                                                                                                                "I am a candidate. I have not withdrawn."
# 16233                                                                                                               "You don't even have to go outside Obama's campaign to find advisers who are anti-Israel."
# 16242                                                                                                                "John McCain says it's okay with him if the U.S. spends the next thousand years in Iraq."
# 16293                                                                                                                                    "(John McCain) was even mentioned as a running mate with John Kerry."
# 16393                                                                                "And, you know, our first president and our first commander in chief prayed every day. He had a field manual of prayers."
# 16401                                                                               "We've got some 37-million of our fellow citizens who are living in poverty; about 12-million or 13-million are children."
# 16420                     "I spend a lot of time in Iowa, and believe it or not, in Ottumwa, Iowa, this is the heartland, the newspaper, the regular newspaper for Ottumwa, Iowa, is (a) bilingual newspaper."
# 16445                                                                                                                  "Congress' approval rating is 11 percent. You know who's higher? Dick Cheney and HMOs."
# 16446                                                                                  "Three out of the 18 benchmarks of the (GAO) have been fulfilled. Even among Republican math, that is a failing grade."
# 16473                                                                                                                           "Dodd brought both parties together to pass the Family and Medical Leave Act."
# 16504                                                                               "This (SCHIP) is socialized medicine. It is going to go to families that make $60,000 a year. Those aren't poor children."
# 16552                                                                                                                                                                                "I'm pro-life. He's not."
# 16557                                                                            "Iowa, for good reason, for constitutional reasons, for reasons related to the Lord, should be the first caucus and primary."
# 16576                                                                                                                                    "Currently, we're at 36 percent of our children born out of wedlock."
# 16583                                                           "In 1972, we had a 179,000 human beings in jail in this country. Today, it's 2.3-million, and 70 percent of them are black, African-American."
# 16602                                                                                                                                     "I'm for a three-state political solution in Iraq. (Romney) is not."
# 16606                                  "For every single scientist that tells you (global warming is) happening and that it's our fault...I can stack up another group of reports that say just the opposite."
# 16609                         "Tommy Thompson is the father of welfare reform, creating the groundbreaking Wisconsin Works program in Wisconsin that became the model for national and international reforms."
# 16610  "Tommy Thompson created the first school choice program in the nation, giving thousands of Milwaukee students the choice of where they go to school – no matter where they live or how much money th...
#
#              veracity
# 18              False
# 21               True
# 27              False
# 30     Pants on Fire!
# 42              False
# 61               True
# 64               True
# 73              False
# 76     Pants on Fire!
# 85     Pants on Fire!
# 91               True
# 168              True
# 179             False
# 180              True
# 186              True
# 208             False
# 220    Pants on Fire!
# 226             False
# 265              True
# 290             False
# 295    Pants on Fire!
# 302             False
# 339             False
# 348             False
# 370    Pants on Fire!
# 397             False
# 409              True
# 424             False
# 468              True
# 471             False
# ...               ...
# 15815           False
# 15876            True
# 15977            True
# 15986            True
# 16037            True
# 16038           False
# 16080            True
# 16085            True
# 16119  Pants on Fire!
# 16179            True
# 16201           False
# 16222            True
# 16233           False
# 16242            True
# 16293            True
# 16393           False
# 16401            True
# 16420           False
# 16445           False
# 16446            True
# 16473            True
# 16504            True
# 16552           False
# 16557  Pants on Fire!
# 16576            True
# 16583  Pants on Fire!
# 16602            True
# 16606           False
# 16609            True
# 16610            True
#
# [1455 rows x 5 columns]

# %%
cleaned_df.to_csv('politifact_cleaned_data.csv')
