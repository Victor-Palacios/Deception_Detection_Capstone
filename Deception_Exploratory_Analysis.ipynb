# %% [markdown]
# # Summary
#
# ## Features engineered from raw statements
# No. of characters
#
# No. of words
#
# Avg. length of words
#
# Readability score
#
# POS (part of speech): Is this word an adjective, noun, something else?
#
# NER (named entity recognition tagging): tags the kind of noun--person, place, organization, etc.--among other things
#
# SD (syntatic dependency): the relation between tokens
#
# ## Statistics
#
# ### Significantly higher for Truth
# Statement Count: Character & Word count
#
# General (15 tags) POS tagging: adj., conjunction+ (i.e., "of", "about", "to", etc.), noun, number, determiner (i.e., "a", "an", "the")
#
# Specific (52 tags) POS tagging: cardinal numbers, determiners, conjunctions(subordinating or preposition), adjective(comparative), noun(singular or mass)
#
# NER: references to dates, percentages, numbers
#
# SD: adjectival modifier, determiner, numeric modifier, object of preposition, prepositional modifier
#
# ### Significantly higher for Falsehoods
# Statement Length: Average word length
#
# Specific (52 tags) POS tagging: verb (modal auxiliary), superfluous punctuation
#
# NER: references to people
#
# SD: clausal complement, clausal subject
#
# ### Run Time
# Running this notebook from start to finish takes 23 minutes because of the tagging

# %%
# import packages if not on computer

# import sys
# !{sys.executable} -m pip install textatistic
# !{sys.executable} -m pip install spacy
# !{sys.executable} -m spacy download en_core_web_sm # doesn't include word vectors
# !{sys.executable} -m spacy download en_core_web_md # includes word vectors

# %%
# for Data Manipulation
import pandas as pd
import numpy as np
import os
import csv 

# for EDA
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline   
from collections import Counter

# for NLP
from textatistic import Textatistic
import spacy
from spacy import displacy

# for Statistics
from scipy import stats

# %%
# Use cleaner absolute path to find file
path = os.path.abspath('politifact_cleaned_data.csv')
df = pd.read_csv(path, index_col=0)

# to see statement in full
pd.set_option('display.max_colwidth', 200) 

# See sample of data
df.head(3)
# Out:
#           date             source  freq  \
# 18  2019-10-23  Jeremy Thiesfeldt     1
# 21  2019-10-22       Brett McGurk     1
# 27  2019-10-21      Beto O'Rourke     3
#
#                                                                                                                                                                                                   statement  \
# 18                                                                                                            "The vast majority of Wisconsin students cannot even read, write, or do math at grade level."
# 21  "President Trump has sent 14,000 American troops to the (Middle East) region since May. So he can't tell his political rallies that he's getting troops out of endless wars when he's sending 14 tim...
# 27                                                                                                                                        "To be clear, I’m not talking about confiscating anybody’s guns."
#
#    veracity  length
# 18    False      93
# 21     True     232
# 27    False      65

# %% [markdown]
# # Dataframe column label explanations
# date = date statement was made
#
# source = source of statement
#
# freq = frequency which source occurs in dataframe
#
# statement = the statement which was evaluated for veracity at https://www.politifact.com
#
# veracity = the truthfulness of a statement

# %%
df.veracity.value_counts()
# Out:
# False             576
# True              571
# Pants on Fire!    308
# Name: veracity, dtype: int64

# %% [markdown]
# # Preprocessing Steps: Creating a condensed (lemmatized) text
# Start: Original Text
#
# 1) Lowercasing: Examples -> examples
#
# 2) Reduction to root form: examples -> example
#
# End: Lemmatized Text

# %% [markdown]
# # Other Text Preprocessing Techniques
# removing whitespaces, punctuation, stopwords, special characters (numbers, etc.), html/xml tags
#
# expanding contractions (may not be needed if stopwords removed since contracted words are typically stopwords)
#
# replacing accented characters
#
# correcting spelling errors

# %%
nlp = spacy.load('en_core_web_md')

# %%
# lemmatization function
def lemmatize(text):
    # create nlp object
    nobj = nlp(text)
    
    # stopword list from spacy
    stopwords = spacy.lang.en.stop_words.STOP_WORDS
    
    # simple lemmas
    lemmas = [token.lemma_ for token in nobj]
    
    # lowercase; remove non-alphabetic characters & overly used words, i.e., stop words
    a_lemmas = [lemma.lower() for lemma in lemmas
                if lemma.isalpha() 
                and lemma not in stopwords]
    
    # strings
    strings = " ".join(a_lemmas)
    
    return strings

# %%
# sample: removes whitespaces, puncuation, stopwords, special characters; converts to lowercase
lemmatize(" ! i don't, won't,   can't not use    NLP 27x maaaah?")
# Out:
# 'use nlp maaaah'

# %%
df["lemmas"] = df.statement.apply(lemmatize)

# %%
df[500:1500:500]
# Out:
#              date        source  freq  \
# 5223   2016-03-10    Jeff DeWit     1
# 11381  2012-03-13  Hank Johnson     1
#
#                                                                                                                                                                                  statement  \
# 5223                                                                                                                              "Now we have ISIS coming over the (U.S.-Mexico) border."
# 11381  "In the last two years, super PACs raised more than $180 million -- with roughly half of it coming from fewer than 200 super-rich people and roughly 20 percent from corporations."
#
#       veracity  length  \
# 5223     False      56
# 11381     True     179
#
#                                                                                               lemmas
# 5223                                                                                isis come border
# 11381  year super pacs raise million roughly half come super rich people roughly percent corporation

# %% [markdown]
# # Tagging Text
# POS (parts of speech; POS Tagging): Is this word an adjective, noun, something else?
#
# NER (named entity recognition tagging; tags the kind of noun--person, place, organization, etc.--among other things)
#
# SD (syntatic dependency): the relation between tokens

# %% [markdown]
# # Part of Speech (POS) Tagging

# %% [markdown]
# ## .pos_ (general pos tagging -- 16 tags)
# #### .pos_ tags are based on the Google Universal POS Tags (spaCy extends the list)

# %%
# .pos_ example
nobj = nlp(df.statement[21])
pos = [(token.text, token.pos_) for token in nobj]
print(pos)
# Out:
# [('"', 'PUNCT'), ('President', 'PROPN'), ('Trump', 'PROPN'), ('has', 'AUX'), ('sent', 'VERB'), ('14,000', 'NUM'), ('American', 'ADJ'), ('troops', 'NOUN'), ('to', 'ADP'), ('the', 'DET'), ('(', 'PUNCT'), ('Middle', 'PROPN'), ('East', 'PROPN'), (')', 'PUNCT'), ('region', 'NOUN'), ('since', 'SCONJ'), ('May.', 'PROPN'), ('So', 'ADV'), ('he', 'PRON'), ('ca', 'VERB'), ("n't", 'PART'), ('tell', 'VERB'), ('his', 'PRON'), ('political', 'ADJ'), ('rallies', 'NOUN'), ('that', 'SCONJ'), ('he', 'PRON'), ("'s", 'AUX'), ('getting', 'VERB'), ('troops', 'NOUN'), ('out', 'SCONJ'), ('of', 'ADP'), ('endless', 'ADJ'), ('wars', 'NOUN'), ('when', 'ADV'), ('he', 'PRON'), ("'s", 'AUX'), ('sending', 'VERB'), ('14', 'NUM'), ('times', 'NOUN'), ('the', 'DET'), ('amount', 'NOUN'), ('back', 'ADV'), ('into', 'ADP'), ('the', 'DET'), ('region', 'NOUN'), ('.', 'PUNCT'), ('"', 'PUNCT')]

# %%
def dot_pos_tagger(text):
    # nlp object
    nobj = nlp(text)
    # POS tags
    tagged_text = [(token.text, token.pos_) for token in nobj]
    # tagged text
    return tagged_text

df["general_pos_tags"] = df.statement.apply(dot_pos_tagger)

# %%
df[["general_pos_tags"]][0:2]
# Out:
#                                                                                                                                                                                            general_pos_tags
# 18  [(", PUNCT), (The, DET), (vast, ADJ), (majority, NOUN), (of, ADP), (Wisconsin, PROPN), (students, NOUN), (can, VERB), (not, PART), (even, ADV), (read, VERB), (,, PUNCT), (write, VERB), (,, PUNCT),...
# 21  [(", PUNCT), (President, PROPN), (Trump, PROPN), (has, AUX), (sent, VERB), (14,000, NUM), (American, ADJ), (troops, NOUN), (to, ADP), (the, DET), ((, PUNCT), (Middle, PROPN), (East, PROPN), (), PU...

# %%
# a more visual rendering of the above
displacy.render(nobj, 
                style = "dep", # styles are dep (dependency) or ent (entity)
                jupyter = True,
                options = {
                          "distance" : 125,
                          "arrow_stroke" : 2, # thickness of arrow line
                          "arrow_width" : 8, # thickness of arrow head
                          "bg" : "#EDEDED" # background color
                         })
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f425ed0484584d05a41757c4998d13b8-0" class="displacy" width="5550" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #EDEDED; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="175">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="175">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="300">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="300">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="425">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="425">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="550">sent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="675">14,000</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="675">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="800">American</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">troops</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1050">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1175">the (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1175">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1300">Middle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1300">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1425">East)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1550">region</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1675">since</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1675">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">May.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1925">So</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2050">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2175">ca</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2175">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2300">n't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2425">tell</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2550">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">political</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2800">rallies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2925">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2925">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3050">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3175">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3175">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3300">getting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3425">troops</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">out</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3675">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3800">endless</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">ADJ</tspan>
# </text

# %% [markdown]
# the tagger works

# %% [markdown]
# ## .tag_ (specific pos tagging -- 53 tags)
# #### .tag_ uses OntoNotes 5 from the Penn Treebank tag set

# %%
# .tag_ example (more specific pos tagging)
nobj = nlp(df.statement[21])
pos = [(token.text, token.tag_) for token in nobj]
print(pos)
# Out:
# [('"', '``'), ('President', 'NNP'), ('Trump', 'NNP'), ('has', 'VBZ'), ('sent', 'VBN'), ('14,000', 'CD'), ('American', 'JJ'), ('troops', 'NNS'), ('to', 'IN'), ('the', 'DT'), ('(', '-LRB-'), ('Middle', 'NNP'), ('East', 'NNP'), (')', '-RRB-'), ('region', 'NN'), ('since', 'IN'), ('May.', 'NNP'), ('So', 'RB'), ('he', 'PRP'), ('ca', 'MD'), ("n't", 'RB'), ('tell', 'VB'), ('his', 'PRP$'), ('political', 'JJ'), ('rallies', 'NNS'), ('that', 'IN'), ('he', 'PRP'), ("'s", 'VBZ'), ('getting', 'VBG'), ('troops', 'NNS'), ('out', 'IN'), ('of', 'IN'), ('endless', 'JJ'), ('wars', 'NNS'), ('when', 'WRB'), ('he', 'PRP'), ("'s", 'VBZ'), ('sending', 'VBG'), ('14', 'CD'), ('times', 'NNS'), ('the', 'DT'), ('amount', 'NN'), ('back', 'RB'), ('into', 'IN'), ('the', 'DT'), ('region', 'NN'), ('.', '.'), ('"', "''")]

# %%
def dot_tag_tagger(text):
    # nlp object
    nobj = nlp(text)
    # tags
    tagged_text = [(token.text, token.tag_) for token in nobj]
    # tagged text
    return tagged_text

df["specific_pos_tags"] = df.statement.apply(dot_tag_tagger)

# %%
df[["specific_pos_tags"]][0:2]
# Out:
#                                                                                                                                                                                           specific_pos_tags
# 18  [(", ``), (The, DT), (vast, JJ), (majority, NN), (of, IN), (Wisconsin, NNP), (students, NNS), (can, MD), (not, RB), (even, RB), (read, VB), (,, ,), (write, VBP), (,, ,), (or, CC), (do, VB), (math,...
# 21  [(", ``), (President, NNP), (Trump, NNP), (has, VBZ), (sent, VBN), (14,000, CD), (American, JJ), (troops, NNS), (to, IN), (the, DT), ((, -LRB-), (Middle, NNP), (East, NNP), (), -RRB-), (region, NN...

# %% [markdown]
# # NER (named-entity recognition) tagging

# %%
# NER example
displacy.render(nobj, style = "ent", jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">&quot;President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has sent
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  troops to the (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Middle East
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ) region since May. So he can't tell his political rallies that he's getting troops out of endless wars when he's sending
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  times the amount back into the region.&quot;</div>

# %%
# ner function
def ner_tagger(text):
    # nlp object
    nobj = nlp(text)
    # ner tags
    ne = [(ent.text, ent.label_) for ent in nobj.ents]
    return ne

# %%
df["ner_tags"] = df.statement.apply(ner_tagger)

# %%
df[["ner_tags"]][0:2]
# Out:
#                                                                                        ner_tags
# 18                                                                           [(Wisconsin, GPE)]
# 21  [(Trump, PERSON), (14,000, CARDINAL), (American, NORP), (Middle East, LOC), (14, CARDINAL)]

# %% [markdown]
# # SD (Syntatic Dependency) tagging

# %%
# .tag_ example (more specific pos tagging)
nobj = nlp(df.statement[21])
sd = [(token.text, token.dep_) for token in nobj]
print(sd)
# Out:
# [('"', 'punct'), ('President', 'compound'), ('Trump', 'nsubj'), ('has', 'aux'), ('sent', 'ROOT'), ('14,000', 'nummod'), ('American', 'amod'), ('troops', 'dobj'), ('to', 'dative'), ('the', 'det'), ('(', 'punct'), ('Middle', 'nmod'), ('East', 'nmod'), (')', 'punct'), ('region', 'pobj'), ('since', 'prep'), ('May.', 'pobj'), ('So', 'advmod'), ('he', 'nsubj'), ('ca', 'aux'), ("n't", 'neg'), ('tell', 'ROOT'), ('his', 'poss'), ('political', 'amod'), ('rallies', 'dobj'), ('that', 'mark'), ('he', 'nsubj'), ("'s", 'aux'), ('getting', 'ccomp'), ('troops', 'dobj'), ('out', 'prep'), ('of', 'prep'), ('endless', 'amod'), ('wars', 'pobj'), ('when', 'advmod'), ('he', 'nsubj'), ("'s", 'aux'), ('sending', 'advcl'), ('14', 'nummod'), ('times', 'quantmod'), ('the', 'det'), ('amount', 'dobj'), ('back', 'advmod'), ('into', 'prep'), ('the', 'det'), ('region', 'pobj'), ('.', 'punct'), ('"', 'punct')]

# %%
# sd function
def sd_tagger(text):
    # nlp object
    nobj = nlp(text)
    # tags
    tagged_text = [(token.text, token.dep_) for token in nobj]
    # tagged text
    return tagged_text

df["sd_tags"] = df.statement.apply(sd_tagger)

# %%
df[["sd_tags"]][0:2]
# Out:
#                                                                                                                                                                                                     sd_tags
# 18  [(", punct), (The, det), (vast, amod), (majority, nsubj), (of, prep), (Wisconsin, compound), (students, pobj), (can, aux), (not, neg), (even, advmod), (read, ROOT), (,, punct), (write, conj), (,, ...
# 21  [(", punct), (President, compound), (Trump, nsubj), (has, aux), (sent, ROOT), (14,000, nummod), (American, amod), (troops, dobj), (to, dative), (the, det), ((, punct), (Middle, nmod), (East, nmod)...

# %% [markdown]
# # Feature Engineering from the original text and its lemma version
# No. of characters
#
# No. of words
#
# Avg. length of words

# %%
# no. of characters
df["statement_char_count"] = df.statement.apply(len)

# %%
# no. of words function
def word_counter(text):
    
    # split text by blank spaces
    words = text.split()
    
    # count words
    return len(words)

# %%
# no. of words
df["statement_word_count"] = df.statement.apply(word_counter)

# %%
# avg. word length function
def avg_word_length(text):
    
    # split text into words
    words = text.split()
    
    # length of each word
    word_lengths = [len(w) for w in words] 
    
    # avg length
    avg_length = sum(word_lengths)/len(word_lengths)     
    return round((avg_length),1)

# %%
# avg. word length
df["statement_avg_word_len"] = df.statement.apply(avg_word_length)

# %%
df.head(3)
# Out:
#           date             source  freq  \
# 18  2019-10-23  Jeremy Thiesfeldt     1
# 21  2019-10-22       Brett McGurk     1
# 27  2019-10-21      Beto O'Rourke     3
#
#                                                                                                                                                                                                   statement  \
# 18                                                                                                            "The vast majority of Wisconsin students cannot even read, write, or do math at grade level."
# 21  "President Trump has sent 14,000 American troops to the (Middle East) region since May. So he can't tell his political rallies that he's getting troops out of endless wars when he's sending 14 tim...
# 27                                                                                                                                        "To be clear, I’m not talking about confiscating anybody’s guns."
#
#    veracity  length  \
# 18    False      93
# 21     True     232
# 27    False      65
#
#                                                                                                                 lemmas  \
# 18                                                         vast majority wisconsin student read write math grade level
# 21  president trump send american troop middle east region may tell political rally troop endless war send time region
# 27                                                                                   clear talk confiscate anybody gun
#
#                                                                                                                                                                                            general_pos_tags  \
# 18  [(", PUNCT), (The, DET), (vast, ADJ), (majority, NOUN), (of, ADP), (Wisconsin, PROPN), (students, NOUN), (can, VERB), (not, PART), (even, ADV), (read, VERB), (,, PUNCT), (write, VERB), (,, PUNCT),...
# 21  [(", PUNCT), (President, PROPN), (Trump, PROPN), (has, AUX), (sent, VERB), (14,000, NUM), (American, ADJ), (troops, NOUN), (to, ADP), (the, DET), ((, PUNCT), (Middle, PROPN), (East, PROPN), (), PU...
# 27  [(", PUNCT), (To, PART), (be, AUX), (clear, ADJ), (,, PUNCT), (I, PRON), (’m, VERB), (not, PART), (talking, VERB), (about, ADP), (confiscating, VERB), (anybody, PRON), (’s, NOUN), (guns, NOUN), (....
#
#                                                                                                                                                                                           specific_pos_tags  \
# 18  [(", ``), (The, DT), (vast, JJ), (majority, NN), (of, IN), (Wisconsin, NNP), (students, NNS), (can, MD), (not, RB), (even, RB), (read, VB), (,, ,), (write, VBP), (,, ,), (or, CC), (do, VB), (math,...
# 21  [(", ``), (President, NNP), (Trump, NNP), (has, VBZ), (sent, VBN), (14,000, CD), (American, JJ), (troops, NNS), (to, IN), (the, DT), ((, -LRB-), (Middle, NNP), (East, NNP), (), -RRB-), (region, NN...
# 27              [(", ``), (To, TO), (be, VB), (clear, JJ), (,, ,), (I, PRP), (’m, VBP), (not, RB), (talking, VBG), (about, IN), (confiscating, VBG), (anybody, NN), (’s, NN), (guns, NNS), (., .), (", '')]
#
#                                                                                        ner_tags  \
# 18                                                                           [(Wisconsin, GPE)]
# 21  [(Trump, PERSON), (14,000, CARDINAL), (American, NORP), (Middle East, LOC), (14, CARDINAL)]
# 27                                                                                           []
#
#                                                                                                                                                                                                     sd_tags  \
# 18  [(", punct), (The, det), (vast, amod), (majority, nsubj), (of, prep), (Wisconsin, compound), (students, pobj), (can, aux), (not, neg), (even, advmod), (read, ROOT), (,, punct), (write, conj), (,, ...
# 21  [(", punct), (President, compound), (Trump, nsubj), (has, aux), (sent, ROOT), (14,000, nummod), (American, amod), (troops, dobj), (to, dative), (the, det), ((, punct), (Middle, nmod), (East, nmod)...
# 27  [(", punct), (To, aux), (be, advcl), (clear, acomp), (,, punct), (I, nsubj), (’m, aux), (not, neg), (talking, ROOT), (about, prep), (confiscating, pcomp), (anybody, poss), (’s, case), (guns, dobj)...
#
#     statement_char_count  statement_word_count  statement_avg_word_len
# 18                    93                    16                     4.9
# 21                   232                    40                     4.8
# 27                    65                    10                     5.6

# %% [markdown]
# # statistics

# %%
# func for comparing truth vs lie
def tvsf(column_label):
    
    # t & f variables
    truths = df[df['veracity'] == 'True'][column_label]
    falsehoods = df[df['veracity'] == 'False'][column_label]
    
    # means
    truths_mean = round(truths.mean(), 1)
    falsehoods_mean = round(falsehoods.mean(), 1)
    
    # t-test
    t,p = stats.ttest_ind(truths,
                          falsehoods, 
                          equal_var = False)
    if p <= 0.05:
        print("!!! SIGNIFICANT !!!")
        print(column_label, "p-value:", "{:.3f}".format(p))
    else:
        print("-Not Sgnfcnt-")
        print(column_label, "p-value:", "{:.3f}".format(p))
    print("T Avg.", column_label, ":", truths_mean)
    print("F Avg.", column_label, ":", falsehoods_mean)

# %%
tvsf("statement_char_count")
# Out:
# !!! SIGNIFICANT !!!
# statement_char_count p-value: 0.042
# T Avg. statement_char_count : 108.8
# F Avg. statement_char_count : 103.4

# %%
tvsf("statement_word_count")
# Out:
# !!! SIGNIFICANT !!!
# statement_word_count p-value: 0.021
# T Avg. statement_word_count : 18.4
# F Avg. statement_word_count : 17.3

# %%
tvsf("statement_avg_word_len")
# Out:
# !!! SIGNIFICANT !!!
# statement_avg_word_len p-value: 0.003
# T Avg. statement_avg_word_len : 5.0
# F Avg. statement_avg_word_len : 5.2

# %% [markdown]
# #### Character & Word count are statistically higher for Truth
# #### Average word length is statistically higher for Falsehoods
# #### Hypothesis: Truthful people say more with a less sophisticated vocabulary

# %% [markdown]
# # lemma statistics

# %%
# with try and except
# b/c some lemmas do not contain words
def try_avg_word_len(text):
    try:
        return round(avg_word_length(text),1)
    except ZeroDivisionError:
        return 0

df["lemma_char_count"] = df.lemmas.apply(len)
df["lemma_word_count"] = df.lemmas.apply(word_counter)
df["lemma_avg_word_len"] = df.lemmas.apply(try_avg_word_len)

# %%
df.head(2)
# Out:
#           date             source  freq  \
# 18  2019-10-23  Jeremy Thiesfeldt     1
# 21  2019-10-22       Brett McGurk     1
#
#                                                                                                                                                                                                   statement  \
# 18                                                                                                            "The vast majority of Wisconsin students cannot even read, write, or do math at grade level."
# 21  "President Trump has sent 14,000 American troops to the (Middle East) region since May. So he can't tell his political rallies that he's getting troops out of endless wars when he's sending 14 tim...
#
#    veracity  length  \
# 18    False      93
# 21     True     232
#
#                                                                                                                 lemmas  \
# 18                                                         vast majority wisconsin student read write math grade level
# 21  president trump send american troop middle east region may tell political rally troop endless war send time region
#
#                                                                                                                                                                                            general_pos_tags  \
# 18  [(", PUNCT), (The, DET), (vast, ADJ), (majority, NOUN), (of, ADP), (Wisconsin, PROPN), (students, NOUN), (can, VERB), (not, PART), (even, ADV), (read, VERB), (,, PUNCT), (write, VERB), (,, PUNCT),...
# 21  [(", PUNCT), (President, PROPN), (Trump, PROPN), (has, AUX), (sent, VERB), (14,000, NUM), (American, ADJ), (troops, NOUN), (to, ADP), (the, DET), ((, PUNCT), (Middle, PROPN), (East, PROPN), (), PU...
#
#                                                                                                                                                                                           specific_pos_tags  \
# 18  [(", ``), (The, DT), (vast, JJ), (majority, NN), (of, IN), (Wisconsin, NNP), (students, NNS), (can, MD), (not, RB), (even, RB), (read, VB), (,, ,), (write, VBP), (,, ,), (or, CC), (do, VB), (math,...
# 21  [(", ``), (President, NNP), (Trump, NNP), (has, VBZ), (sent, VBN), (14,000, CD), (American, JJ), (troops, NNS), (to, IN), (the, DT), ((, -LRB-), (Middle, NNP), (East, NNP), (), -RRB-), (region, NN...
#
#                                                                                        ner_tags  \
# 18                                                                           [(Wisconsin, GPE)]
# 21  [(Trump, PERSON), (14,000, CARDINAL), (American, NORP), (Middle East, LOC), (14, CARDINAL)]
#
#                                                                                                                                                                                                     sd_tags  \
# 18  [(", punct), (The, det), (vast, amod), (majority, nsubj), (of, prep), (Wisconsin, compound), (students, pobj), (can, aux), (not, neg), (even, advmod), (read, ROOT), (,, punct), (write, conj), (,, ...
# 21  [(", punct), (President, compound), (Trump, nsubj), (has, aux), (sent, ROOT), (14,000, nummod), (American, amod), (troops, dobj), (to, dative), (the, det), ((, punct), (Middle, nmod), (East, nmod)...
#
#     statement_char_count  statement_word_count  statement_avg_word_len  \
# 18                    93                    16                     4.9
# 21                   232                    40                     4.8
#
#     lemma_char_count  lemma_word_count  lemma_avg_word_len
# 18                59                 9                 5.7
# 21               114                18                 5.4

# %%
tvsf("lemma_char_count")
print("")
tvsf("lemma_word_count")
print("")
tvsf("lemma_avg_word_len")
# Out:
# -Not Sgnfcnt-
# lemma_char_count p-value: 0.293
# T Avg. lemma_char_count : 60.7
# F Avg. lemma_char_count : 59.0
#
# -Not Sgnfcnt-
# lemma_word_count p-value: 0.292
# T Avg. lemma_word_count : 8.7
# F Avg. lemma_word_count : 8.5
#
# -Not Sgnfcnt-
# lemma_avg_word_len p-value: 0.884
# T Avg. lemma_avg_word_len : 6.1
# F Avg. lemma_avg_word_len : 6.1

# %% [markdown]
# ### With lemmatization, statements lose significant differences in terms of length, etc.
# ### It appears that words which spaCy finds meaningless and then discards, may be meaningful for deception detection

# %% [markdown]
# # More Features that can be engineered
# No. of sentences
#
# No. of paragraphs
#
# Words starting with an uppercase
#
# All-capital words
#
# Numeric quantities
#
# Readability Score

# %% [markdown]
# # Readability Tests

# %%
# readability func
def readability(text):    
    # scores
    readability_scores = Textatistic(text).scores
    """ 
    Gunning Fog Score depends on sentence length and syllable amount
    17 = College Graduate
    ...
    6 = 6th grade
    """
    gunningfog_score = readability_scores["gunningfog_score"]
    return gunningfog_score

# with try and except
# b/c some sentences do not end with a period
def readability_try(text):
    try:
        return round(readability(text),1)
    except ZeroDivisionError:
        return 0

# %%
# readability scores
df["read_score_gun"] = df.statement.apply(readability_try)

# %%
df[10:100:50]
# Out:
#            date      source  freq  \
# 91   2019-10-01  Gwen Moore     3
# 755  2019-04-02   Kaye Kory     1
#
#                                                                                                                                          statement  \
# 91                                                                                    "More than half of death row prisoners are people of color."
# 755  "Women in Virginia have been incarcerated at an increasingly high rate. It’s around (a) 300 percent increase in the past four or five years."
#
#     veracity  length  \
# 91      True      60
# 755    False     141
#
#                                                                            lemmas  \
# 91                                      more half death row prisoner people color
# 755  women virginia incarcerate increasingly high rate percent increase past year
#
#                                                                                                                                                                                             general_pos_tags  \
# 91            [(", PUNCT), (More, ADJ), (than, SCONJ), (half, NOUN), (of, ADP), (death, NOUN), (row, NOUN), (prisoners, NOUN), (are, AUX), (people, NOUN), (of, ADP), (color, NOUN), (., PUNCT), (", PUNCT)]
# 755  [(", PUNCT), (Women, PROPN), (in, ADP), (Virginia, PROPN), (have, AUX), (been, AUX), (incarcerated, VERB), (at, ADP), (an, DET), (increasingly, ADV), (high, ADJ), (rate, NOUN), (., PUNCT), (It, PR...
#
#                                                                                                                                                                                            specific_pos_tags  \
# 91                                     [(", ``), (More, JJR), (than, IN), (half, NN), (of, IN), (death, NN), (row, NN), (prisoners, NNS), (are, VBP), (people, NNS), (of, IN), (color, NN), (., .), (", '')]
# 755  [(", ``), (Women, NNP), (in, IN), (Virginia, NNP), (have, VBP), (been, VBN), (incarcerated, VBN), (at, IN), (an, DT), (increasingly, RB), (high, JJ), (rate, NN), (., .), (It, PRP), (’s, VBZ), (aro...
#
#                                                                            ner_tags  \
# 91                                                     [(More than half, CARDINAL)]
# 755  [(Virginia, GPE), (300 percent, PERCENT), (the past four or five years, DATE)]
#
#                                                                                                                                                                                                      sd_tags  \
# 91   [(", punct), (More, amod), (than, quantmod), (half, nsubj), (of, prep), (death, compound), (row, compound), (prisoners, pobj), (are, ROOT), (people, attr), (of, prep), (color, pobj), (., punct), (...
# 755  [(", punct), (Women, nsubjpass), (in, prep), (Virginia, pobj), (have, aux), (been, auxpass), (incarcerated, ROOT), (at, prep), (an, det), (increasingly, advmod), (high, amod), (rate, pobj), (., pu...
#
#      statement_char_count  statement_word_count  statement_avg_word_len  \
# 91                     60                    11                     4.5
# 755                   141                    24                     4.9
#
#      lemma_char_count  lemma_word_count  lemma_avg_word_len  read_score_gun
# 91                 41                 7                 5.0             8.0
# 755                76                10                 6.7             8.1

# %%
tvsf("read_score_gun")
# Out:
# -Not Sgnfcnt-
# read_score_gun p-value: 0.511
# T Avg. read_score_gun : 9.7
# F Avg. read_score_gun : 9.5

# %% [markdown]
# #### reading score (i.e., sentence length and syllable count) doesn't appear tied to lies or truths;

# %% [markdown]
# next, we should also examine if certain kinds of words appear more often in falsehoods than in truths like adjectives or nouns

# %% [markdown]
# # POS dictionaries and lists for statistics

# %% [markdown]
# ### .pos_ tag's dictionary and list

# %%
# first we need a dictionary and list of all the possible tags
# csv made from https://spacy.io/api/annotation#pos-tagging
# here's a df of all .pos_ tags for ease of readabilty
path = os.path.abspath('pos.csv')
dot_pos_df = pd.read_csv(path)
dot_pos_df[["POS","description"]][0:2]
# Out:
#    POS                        description
# 0  ADJ                          adjective
# 1  ADP  conjunction or particle or adverb

# %%
len(dot_pos_df)
# Out:
# 16

# %%
# .pos_ tags in dictionary form
with open('pos.csv', mode='r') as infile:
    reader = csv.reader(infile)
    with open('pos_dict.csv', mode='w') as outfile:
        writer = csv.writer(outfile)
        mydict_pos = {rows[0]:rows[1] for rows in reader}

# %%
# preview dictionary
list(mydict_pos.items())[0:3]
# Out:
# [('POS', 'description'),
#  ('ADJ', 'adjective'),
#  ('ADP', 'conjunction or particle or adverb')]

# %%
# delete first entry in dict, i.e., column labels
del mydict_pos["POS"]

# %%
# we'll use this to automate later tasks
dot_pos_list = list(mydict_pos.keys())
print(dot_pos_list[0:3])
# Out:
# ['ADJ', 'ADP', 'ADV']

# %% [markdown]
# ### .tag_ tag's dictionary and list

# %%
# df of all .tag_ tags for ease of readabilty
# csv made from https://spacy.io/api/annotation#pos-tagging
path = os.path.abspath('tags.csv')
dot_tag_df = pd.read_csv(path)
dot_tag_df[["tag","description"]][0:2]
# Out:
#   tag                               description
# 0  GW  additional word in multi-word expression
# 1  JJ                                 adjective

# %%
len(dot_tag_df)
# Out:
# 53

# %%
# .tag_ in dictionary form
with open('tags.csv', mode='r') as infile:
    reader = csv.reader(infile)
    with open('tags_dict.csv', mode='w') as outfile:
        writer = csv.writer(outfile)
        mydict_tag = {rows[0]:rows[1] for rows in reader}

# %%
list(mydict_tag.items())[8:11]
# Out:
# [('RBS', 'adverb (superlative)'), ('AFX', 'affix'), ('CD', 'cardinal number')]

# %%
# delete first entry in dict, i.e., column labels
del mydict_tag["tag"]

# %%
# we'll use this to automate later tasks
dot_tag_list = list(mydict_tag.keys())
print(dot_tag_list[8:12])
# Out:
# ['AFX', 'CD', 'CC', 'IN']

# %% [markdown]
# # Automating POS tag counts

# %%
def dot_pos_counter(text, p):
    # nlp object
    nobj = nlp(text)
    # list of POS tags
    pos = [token.pos_ for token in nobj]
    # count POS
    return pos.count(p)

# %%
# loop through the list of .pos_ tags and create new columns with counts for each tag
# this takes several minutes
for p in dot_pos_list:
    # df[p] = df.statement.apply(lambda x : proper_nouns(x, p)) #this works; check if below works in 2nd run
    df[("pos_"+mydict_pos[p])] = df.statement.apply(lambda x : dot_pos_counter(x, p))

# %%
def dot_tag_counter(text, t):
    # nlp object
    nobj = nlp(text)
    # list of tags
    tg = [token.tag_ for token in nobj]
    # count
    return tg.count(t)

# %%
# loop through the list of .tag_ tags and create new columns with counts for each tag
# this takes several minutes
for t in dot_tag_list:
    # df[p] = df.statement.apply(lambda x : proper_nouns(x, p)) #this works; check if below works in 2nd run
    df[("tag_"+mydict_tag[t])] = df.statement.apply(lambda x : dot_tag_counter(x, t))

# %%
# to see df in full
pd.set_option('display.max_columns', 200) 

df.head(1)
# Out:
#           date             source  freq  \
# 18  2019-10-23  Jeremy Thiesfeldt     1
#
#                                                                                         statement  \
# 18  "The vast majority of Wisconsin students cannot even read, write, or do math at grade level."
#
#    veracity  length  \
# 18    False      93
#
#                                                          lemmas  \
# 18  vast majority wisconsin student read write math grade level
#
#                                                                                                                                                                                            general_pos_tags  \
# 18  [(", PUNCT), (The, DET), (vast, ADJ), (majority, NOUN), (of, ADP), (Wisconsin, PROPN), (students, NOUN), (can, VERB), (not, PART), (even, ADV), (read, VERB), (,, PUNCT), (write, VERB), (,, PUNCT),...
#
#                                                                                                                                                                                           specific_pos_tags  \
# 18  [(", ``), (The, DT), (vast, JJ), (majority, NN), (of, IN), (Wisconsin, NNP), (students, NNS), (can, MD), (not, RB), (even, RB), (read, VB), (,, ,), (write, VBP), (,, ,), (or, CC), (do, VB), (math,...
#
#               ner_tags  \
# 18  [(Wisconsin, GPE)]
#
#                                                                                                                                                                                                     sd_tags  \
# 18  [(", punct), (The, det), (vast, amod), (majority, nsubj), (of, prep), (Wisconsin, compound), (students, pobj), (can, aux), (not, neg), (even, advmod), (read, ROOT), (,, punct), (write, conj), (,, ...
#
#     statement_char_count  statement_word_count  statement_avg_word_len  \
# 18                    93                    16                     4.9
#
#     lemma_char_count  lemma_word_count  lemma_avg_word_len  read_score_gun  \
# 18                59                 9                 5.7            11.4
#
#     pos_adjective  pos_conjunction or particle or adverb  pos_adverb  \
# 18              1                                      2           1
#
#     pos_coordinating conjuction  pos_determiner  pos_interjection  pos_noun  \
# 18                            1               1                 0         5
#
#     pos_number  pos_possessive  pos_pronoun  pos_proper noun  pos_punctuation  \
# 18           0               1            0                1                5
#
#     pos_space  pos_symbol  pos_verb  pos_unknown  \
# 18          0           0         3            0
#
#     tag_additional word in multi-word expression  tag_adjective  \
# 18                                             0              1
#
#     tag_adjective (comparative)  tag_adjective (superlative)  tag_adverb  \
# 18                            0                            0           2
#
#     tag_adverb (comparative)  tag_adverb (particle)  tag_adverb (superlative)  \
# 18                         0                      0                         0
#
#     tag_affix  tag_cardinal number  tag_conjunction (coordinating)  \
# 18          0                    0                               1
#
#     tag_conjunction (subordinating or preposition)  tag_determiner  tag_email  \
# 18                                               2               1          0
#
#     tag_existential there  tag_foreign word  tag_infinitival “to”  \
# 18                      0                 0                     0
#
#     tag_interjection  tag_list item marker  tag_missing tag  \
# 18                 0                     0                0
#
#     tag_noun (plural)  tag_noun (proper plural)  tag_noun (proper singular)  \
# 18                  1                         0                           1
#
#     tag_noun (singular or mass)  tag_possessive ending  tag_predeterminer  \
# 18                            4                      0                  0
#
#     tag_pronoun (personal)  tag_pronoun (possessive)  \
# 18                       0                         0
#
#     tag_punctuation mark (colon or ellipsis)  tag_punctuation mark (comma)  \
# 18                                         0                             2
#
#     tag_punctuation mark (hyphen)  tag_punctuation mark (sentence closer)  \
# 18                              0                                       1
#
#     tag_quotation mark (closing)  tag_quotation mark (opening)  \
# 18                             0                             1
#
#     tag_round bracket (left)  tag_round bracket (right)  tag_space_01  \
# 18                         0                          0             0
#
#     tag_space_02  tag_superfluous punctuation  tag_symbol  \
# 18             0                            0           0
#
#     tag_symbol (currency)  tag_unknown  \
# 18                      0            0
#
#     tag_verb (3rd person singular present)  tag_verb (base form)  \
# 18                                       0                     2
#
#     tag_verb (gerund or present participle)  tag_verb (modal or auxiliary)  \
# 18                                        0                              1
#
#     tag_verb (non-3rd person singular present)  tag_verb (past participle)  \
# 18                                           1                           0
#
#     tag_verb (past tense)  tag_wh-adverb  tag_wh-determiner  \
# 18                      0              0                  0
#
#     tag_wh-pronoun (personal)  tag_wh-pronoun (possessive)
# 18                          0                            0

# %% [markdown]
# # POS Statistics

# %% [markdown]
# ### .pos_

# %%
""" 
since the tvsf function output would be difficult to read, let's convert to a dataframe output
"""

# func for comparing truth vs lie
def df_tvsf(tag_type, column_dict, index_list):
    #ex: df_tvsf("pos_", mydict_pos, dot_pos_list)
    
    d = []
    for x in index_list:
        
        # t & f variables
        truths = df[df['veracity'] == 'True'][tag_type+column_dict[x]]
        falsehoods = df[df['veracity'] == 'False'][tag_type+column_dict[x]]

        # means
        truths_mean = round(truths.mean(), 2)
        falsehoods_mean = round(falsehoods.mean(), 2)

        # t-test
        t,p = stats.ttest_ind(truths,
                              falsehoods, 
                              equal_var = False)
        # dataframe
        d.append({'t_means' : truths_mean, 
                  'f_means' : falsehoods_mean, 
                  'p_value' : round(p,3)})
        
    return pd.DataFrame(d, index = column_dict.values())[['t_means', 'f_means', 'p_value']]

# %%
# return df with probability values that approach or are significant
dot_pos_df = df_tvsf("pos_", mydict_pos, dot_pos_list)
dot_pos_df[dot_pos_df.p_value < 0.05]
# Out:
#                                    t_means  f_means  p_value
# adjective                             1.42     1.23    0.006
# conjunction or particle or adverb     2.33     2.05    0.002
# determiner                            1.87     1.64    0.006
# noun                                  4.35     3.95    0.002
# number                                0.99     0.72    0.000
# verb                                  1.72     1.89    0.040

# %% [markdown]
# # significantly more likely in truth:
# ### adj., conjunction+ (i.e., "of", "about", "to", etc.), noun, number, & determiner (i.e., "a", "an", "the")
#
# # significantly more likely in falsehoods:
# ### verbs

# %% [markdown]
# ### .tag_

# %%
# return df with probability values that approach or are significant
dot_tag_df = df_tvsf("tag_", mydict_tag, dot_tag_list)
dot_tag_df[dot_tag_df.p_value < 0.05]
# Out:
#                                             t_means  f_means  p_value
# adjective (comparative)                        0.20     0.12    0.001
# cardinal number                                0.99     0.72    0.000
# conjunction (subordinating or preposition)     2.72     2.38    0.001
# determiner                                     1.86     1.63    0.005
# noun (plural)                                  1.39     1.25    0.040
# noun (singular or mass)                        2.98     2.74    0.032
# superfluous punctuation                        0.03     0.05    0.038
# verb (base form)                               0.47     0.57    0.043
# verb (modal or auxiliary)                      0.10     0.17    0.003

# %% [markdown]
# # significantly more likely in truth:
# ### cardinal numbers, determiners, conjunctions(subordinating or preposition), adjective(comparative), noun(singular or mass)
#
# # significantly more likely in falsehoods:
# ### verb (modal auxiliary), superfluous punctuation

# %% [markdown]
# next, we'll see if named entity recognition (identifying people, places, things, etc.) can help detect deception

# %% [markdown]
# # NER dictionary and list for statistics

# %% [markdown]
# #### let's create the NER dictionary instead of importing it this time
# #### from this information found on https://spacy.io/api/annotation#named-entities
# TYPE	DESCRIPTION
# PERSON	People, including fictional.
# NORP	Nationalities or religious or political groups.
# FAC	Buildings, airports, highways, bridges, etc.
# ORG	Companies, agencies, institutions, etc.
# GPE	Countries, cities, states.
# LOC	Non-GPE locations, mountain ranges, bodies of water.
# PRODUCT	Objects, vehicles, foods, etc. (Not services.)
# EVENT	Named hurricanes, battles, wars, sports events, etc.
# WORK_OF_ART	Titles of books, songs, etc.
# LAW	Named documents made into laws.
# LANGUAGE	Any named language.
# DATE	Absolute or relative dates or periods.
# TIME	Times smaller than a day.
# PERCENT	Percentage, including ”%“.
# MONEY	Monetary values, including unit.
# QUANTITY	Measurements, as of weight or distance.
# ORDINAL	“first”, “second”, etc.
# CARDINAL	Numerals that do not fall under another type.

# %%
mydict_ner = {
    "PERSON" : "people",
    "NORP" : "groups",
    "FAC" : "facilities",
    "ORG" : "organizations",
    "GPE" : "regions",
    "LOC" : "landmarks",
    "PRODUCT" : "products",
    "EVENT" : "events",
    "WORK_OF_ART" : "art",
    "LAW" : "laws",
    "LANGUAGE" : "languages",
    "DATE" : "dates",
    "TIME" : "times",
    "PERCENT" : "percentages",
    "MONEY" : "money",
    "QUANTITY" : "quantity",
    "ORDINAL" : "ordinality",
    "CARDINAL" : "numerals" 
}

# %%
# preview dict
list(mydict_ner.items())[0:2]
# Out:
# [('PERSON', 'people'), ('NORP', 'groups')]

# %%
ner_list = list(mydict_ner.keys())

# %%
def ner_counter(text, n):
    # nlp object
    nobj = nlp(text)
    # list of POS tags
    ne = [ent.label_ for ent in nobj.ents]
    # no. of proper nouns
    return ne.count(n)

# %%
# to loop through the list of ner tags and create new columns with counts for each tag
# this takes several minutes
for n in ner_list:
    # df[n] = df.statement.apply(lambda x : proper_nouns(x, n)) #this works
    df[("ner_"+mydict_ner[n])] = df.statement.apply(lambda x : ner_counter(x, n))

# %%
df.head(1)
# Out:
#           date             source  freq  \
# 18  2019-10-23  Jeremy Thiesfeldt     1
#
#                                                                                         statement  \
# 18  "The vast majority of Wisconsin students cannot even read, write, or do math at grade level."
#
#    veracity  length  \
# 18    False      93
#
#                                                          lemmas  \
# 18  vast majority wisconsin student read write math grade level
#
#                                                                                                                                                                                            general_pos_tags  \
# 18  [(", PUNCT), (The, DET), (vast, ADJ), (majority, NOUN), (of, ADP), (Wisconsin, PROPN), (students, NOUN), (can, VERB), (not, PART), (even, ADV), (read, VERB), (,, PUNCT), (write, VERB), (,, PUNCT),...
#
#                                                                                                                                                                                           specific_pos_tags  \
# 18  [(", ``), (The, DT), (vast, JJ), (majority, NN), (of, IN), (Wisconsin, NNP), (students, NNS), (can, MD), (not, RB), (even, RB), (read, VB), (,, ,), (write, VBP), (,, ,), (or, CC), (do, VB), (math,...
#
#               ner_tags  \
# 18  [(Wisconsin, GPE)]
#
#                                                                                                                                                                                                     sd_tags  \
# 18  [(", punct), (The, det), (vast, amod), (majority, nsubj), (of, prep), (Wisconsin, compound), (students, pobj), (can, aux), (not, neg), (even, advmod), (read, ROOT), (,, punct), (write, conj), (,, ...
#
#     statement_char_count  statement_word_count  statement_avg_word_len  \
# 18                    93                    16                     4.9
#
#     lemma_char_count  lemma_word_count  lemma_avg_word_len  read_score_gun  \
# 18                59                 9                 5.7            11.4
#
#     pos_adjective  pos_conjunction or particle or adverb  pos_adverb  \
# 18              1                                      2           1
#
#     pos_coordinating conjuction  pos_determiner  pos_interjection  pos_noun  \
# 18                            1               1                 0         5
#
#     pos_number  pos_possessive  pos_pronoun  pos_proper noun  pos_punctuation  \
# 18           0               1            0                1                5
#
#     pos_space  pos_symbol  pos_verb  pos_unknown  \
# 18          0           0         3            0
#
#     tag_additional word in multi-word expression  tag_adjective  \
# 18                                             0              1
#
#     tag_adjective (comparative)  tag_adjective (superlative)  tag_adverb  \
# 18                            0                            0           2
#
#     tag_adverb (comparative)  tag_adverb (particle)  tag_adverb (superlative)  \
# 18                         0                      0                         0
#
#     tag_affix  tag_cardinal number  tag_conjunction (coordinating)  \
# 18          0                    0                               1
#
#     tag_conjunction (subordinating or preposition)  tag_determiner  tag_email  \
# 18                                               2               1          0
#
#     tag_existential there  tag_foreign word  tag_infinitival “to”  \
# 18                      0                 0                     0
#
#     tag_interjection  tag_list item marker  tag_missing tag  \
# 18                 0                     0                0
#
#     tag_noun (plural)  tag_noun (proper plural)  tag_noun (proper singular)  \
# 18                  1                         0                           1
#
#     tag_noun (singular or mass)  tag_possessive ending  tag_predeterminer  \
# 18                            4                      0                  0
#
#     tag_pronoun (personal)  tag_pronoun (possessive)  \
# 18                       0                         0
#
#     tag_punctuation mark (colon or ellipsis)  tag_punctuation mark (comma)  \
# 18                                         0                             2
#
#     tag_punctuation mark (hyphen)  tag_punctuation mark (sentence closer)  \
# 18                              0                                       1
#
#     tag_quotation mark (closing)  tag_quotation mark (opening)  \
# 18                             0                             1
#
#     tag_round bracket (left)  tag_round bracket (right)  tag_space_01  \
# 18                         0                          0             0
#
#     tag_space_02  tag_superfluous punctuation  tag_symbol  \
# 18             0                            0           0
#
#     tag_symbol (currency)  tag_unknown  \
# 18                      0            0
#
#     tag_verb (3rd person singular present)  tag_verb (base form)  \
# 18                                       0                     2
#
#     tag_verb (gerund or present participle)  tag_verb (modal or auxiliary)  \
# 18                                        0                              1
#
#     tag_verb (non-3rd person singular present)  tag_verb (past participle)  \
# 18                                           1                           0
#
#     tag_verb (past tense)  tag_wh-adverb  tag_wh-determiner  \
# 18                      0              0                  0
#
#     tag_wh-pronoun (personal)  tag_wh-pronoun (possessive)  ner_people  \
# 18                          0                            0           0
#
#     ner_groups  ner_facilities  ner_organizations  ner_regions  ner_landmarks  \
# 18           0               0                  0            1              0
#
#     ner_products  ner_events  ner_art  ner_laws  ner_languages  ner_dates  \
# 18             0           0        0         0              0          0
#
#     ner_times  ner_percentages  ner_money  ner_quantity  ner_ordinality  \
# 18          0                0          0             0               0
#
#     ner_numerals
# 18             0

# %%
# return df with probability values that approach or are significant
ner_df = df_tvsf("ner_", mydict_ner, ner_list)
ner_df[ner_df.p_value < 0.05]
# Out:
#              t_means  f_means  p_value
# people          0.19     0.29    0.003
# regions         0.46     0.38    0.043
# dates           0.39     0.27    0.001
# percentages     0.16     0.10    0.007
# numerals        0.35     0.27    0.033

# %%
len(ner_df)
# Out:
# 18

# %% [markdown]
# ## significantly more likely in truth:
# ### references to dates, percentages, numbers, and regions
#
# ## significantly more likely in falsehoods:
# ### references to people

# %% [markdown]
# # SD (Syntatic Dependency )

# %%
# first we need a dictionary and list of all the possible tags
# csv made from https://spacy.io/api/annotation#pos-tagging
# here's a df of all sd tags for ease of readabilty
path = os.path.abspath('sd.csv')
sd_df = pd.read_csv(path)
sd_df[["LABEL","DESCRIPTION"]][0:2]
# Out:
#    LABEL                                   DESCRIPTION
# 0    acl  clausal modifier of noun (adjectival clause)
# 1  acomp                         adjectival complement

# %%
# .dep tags in dictionary form
with open('sd.csv', mode='r') as infile:
    reader = csv.reader(infile)
    with open('sd_dict.csv', mode='w') as outfile:
        writer = csv.writer(outfile)
        mydict_sd = {rows[0]:rows[1] for rows in reader}

# %%
# preview dictionary
list(mydict_sd.items())[0:3]
# Out:
# [('LABEL', 'DESCRIPTION'),
#  ('acl', 'clausal modifier of noun (adjectival clause)'),
#  ('acomp', 'adjectival complement')]

# %%
# delete first entry in dict, i.e., column labels
del mydict_sd["LABEL"]

# %%
# we'll use this to automate later tasks
sd_list = list(mydict_sd.keys())
print(sd_list[0:3])
# Out:
# ['acl', 'acomp', 'advcl']

# %% [markdown]
# # Automating sd tag counts

# %%
def sd_counter(text, d):
    # nlp object
    nobj = nlp(text)
    # list of tags
    dep = [token.dep_ for token in nobj]
    # count
    return dep.count(d)

# %%
# loop through the list of tags and create new columns with counts for each tag
# this takes several minutes
for d in sd_list:
    df[("sd_"+mydict_sd[d])] = df.statement.apply(lambda x : sd_counter(x, d))

# %%
# to see df in full
pd.set_option('display.max_columns', 200) 

df.head(1)
# Out:
#           date             source  freq  \
# 18  2019-10-23  Jeremy Thiesfeldt     1
#
#                                                                                         statement  \
# 18  "The vast majority of Wisconsin students cannot even read, write, or do math at grade level."
#
#    veracity  length  \
# 18    False      93
#
#                                                          lemmas  \
# 18  vast majority wisconsin student read write math grade level
#
#                                                                                                                                                                                            general_pos_tags  \
# 18  [(", PUNCT), (The, DET), (vast, ADJ), (majority, NOUN), (of, ADP), (Wisconsin, PROPN), (students, NOUN), (can, VERB), (not, PART), (even, ADV), (read, VERB), (,, PUNCT), (write, VERB), (,, PUNCT),...
#
#                                                                                                                                                                                           specific_pos_tags  \
# 18  [(", ``), (The, DT), (vast, JJ), (majority, NN), (of, IN), (Wisconsin, NNP), (students, NNS), (can, MD), (not, RB), (even, RB), (read, VB), (,, ,), (write, VBP), (,, ,), (or, CC), (do, VB), (math,...
#
#               ner_tags  \
# 18  [(Wisconsin, GPE)]
#
#                                                                                                                                                                                                     sd_tags  \
# 18  [(", punct), (The, det), (vast, amod), (majority, nsubj), (of, prep), (Wisconsin, compound), (students, pobj), (can, aux), (not, neg), (even, advmod), (read, ROOT), (,, punct), (write, conj), (,, ...
#
#     statement_char_count  statement_word_count  statement_avg_word_len  \
# 18                    93                    16                     4.9
#
#     lemma_char_count  lemma_word_count  lemma_avg_word_len  read_score_gun  \
# 18                59                 9                 5.7            11.4
#
#     pos_adjective  pos_conjunction or particle or adverb  pos_adverb  \
# 18              1                                      2           1
#
#     pos_coordinating conjuction  pos_determiner  pos_interjection  pos_noun  \
# 18                            1               1                 0         5
#
#     pos_number  pos_possessive  pos_pronoun  pos_proper noun  pos_punctuation  \
# 18           0               1            0                1                5
#
#     pos_space  pos_symbol  pos_verb  pos_unknown  \
# 18          0           0         3            0
#
#     tag_additional word in multi-word expression  tag_adjective  \
# 18                                             0              1
#
#     tag_adjective (comparative)  tag_adjective (superlative)  tag_adverb  \
# 18                            0                            0           2
#
#     tag_adverb (comparative)  tag_adverb (particle)  tag_adverb (superlative)  \
# 18                         0                      0                         0
#
#     tag_affix  tag_cardinal number  tag_conjunction (coordinating)  \
# 18          0                    0                               1
#
#     tag_conjunction (subordinating or preposition)  tag_determiner  tag_email  \
# 18                                               2               1          0
#
#     tag_existential there  tag_foreign word  tag_infinitival “to”  \
# 18                      0                 0                     0
#
#     tag_interjection  tag_list item marker  tag_missing tag  \
# 18                 0                     0                0
#
#     tag_noun (plural)  tag_noun (proper plural)  tag_noun (proper singular)  \
# 18                  1                         0                           1
#
#     tag_noun (singular or mass)  tag_possessive ending  tag_predeterminer  \
# 18                            4                      0                  0
#
#     tag_pronoun (personal)  tag_pronoun (possessive)  \
# 18                       0                         0
#
#     tag_punctuation mark (colon or ellipsis)  tag_punctuation mark (comma)  \
# 18                                         0                             2
#
#     tag_punctuation mark (hyphen)  tag_punctuation mark (sentence closer)  \
# 18                              0                                       1
#
#     tag_quotation mark (closing)  tag_quotation mark (opening)  \
# 18                             0                             1
#
#     tag_round bracket (left)  tag_round bracket (right)  tag_space_01  \
# 18                         0                          0             0
#
#     tag_space_02  tag_superfluous punctuation  tag_symbol  \
# 18             0                            0           0
#
#     tag_symbol (currency)  tag_unknown  \
# 18                      0            0
#
#     tag_verb (3rd person singular present)  tag_verb (base form)  \
# 18                                       0                     2
#
#     tag_verb (gerund or present participle)  tag_verb (modal or auxiliary)  \
# 18                                        0                              1
#
#     tag_verb (non-3rd person singular present)  tag_verb (past participle)  \
# 18                                           1                           0
#
#     tag_verb (past tense)  tag_wh-adverb  tag_wh-determiner  \
# 18                      0              0                  0
#
#     tag_wh-pronoun (personal)  tag_wh-pronoun (possessive)  ner_people  \
# 18                          0                            0           0
#
#     ner_groups  ner_facilities  ner_organizations  ner_regions  ner_landmarks  \
# 18           0               0                  0            1              0
#
#     ner_products  ner_events  ner_art  ner_laws  ner_languages  ner_dates  \
# 18             0           0        0         0              0          0
#
#     ner_times  ner_percentages  ner_money  ner_quantity  ner_ordinality  \
# 18          0                0          0             0               0
#
#     ner_numerals  sd_clausal modifier of noun (adjectival clause)  \
# 18             0                                                0
#
#     sd_adjectival complement  sd_adverbial clause modifier  \
# 18                         0                             0
#
#     sd_adverbial modifier  sd_agent  sd_adjectival modifier  \
# 18                      1         0                       1
#
#     sd_appositional modifier  sd_attribute  sd_auxiliary  \
# 18                         0             0             1
#
#     sd_auxiliary (passive)  sd_case marking  sd_coordinating conjunction  \
# 18                       0                0                            1
#
#     sd_clausal complement  sd_compound  sd_conjunct  sd_copula  \
# 18                      0            2            2          0
#
#     sd_clausal subject  sd_clausal subject (passive)  sd_dative  \
# 18                   0                             0          0
#
#     sd_unclassified dependent  sd_determiner  sd_direct object  sd_expletive  \
# 18                          0              1                 1             0
#
#     sd_interjection  sd_marker  sd_meta modifier  sd_negation modifier  \
# 18                0          0                 0                     1
#
#     sd_noun compound modifier  sd_modifier of nominal  \
# 18                          0                       0
#
#     sd_noun phrase as adverbial modifier  sd_nominal subject  \
# 18                                     0                   1
#
#     sd_nominal subject (passive)  sd_numeric modifier  sd_object predicate  \
# 18                             0                    0                    0
#
#     sd_object  sd_oblique nominal  sd_parataxis  sd_complement of preposition  \
# 18          0                   0             0                             0
#
#     sd_object of preposition  sd_possession modifier  \
# 18                         2                       0
#
#     sd_pre-correlative conjunction  sd_prepositional modifier  sd_particle  \
# 18                               0                          2            0
#
#     sd_punctuation  sd_modifier of quantifier  sd_relative clause modifier  \
# 18               5                          0                            0
#
#     sd_root  sd_open clausal complement
# 18        0                           0

# %% [markdown]
# # SD Statistics

# %%
# return df with probability values that approach or are significant
sd_df = df_tvsf("sd_", mydict_sd, sd_list)
sd_df[sd_df.p_value < 0.05]
# Out:
#                         t_means  f_means  p_value
# adjectival modifier        1.24     1.04    0.003
# clausal complement         0.17     0.26    0.002
# clausal subject            0.01     0.02    0.046
# determiner                 1.76     1.54    0.005
# marker                     0.19     0.26    0.016
# numeric modifier           0.60     0.43    0.000
# object of preposition      2.31     1.94    0.000
# prepositional modifier     2.39     1.99    0.000
# modifier of quantifier     0.21     0.15    0.027

# %%
sd_signif = sd_df[sd_df.p_value < 0.05].iloc[:,0]

sd_target = sd_signif.index.values[8]

plus_sd_target = "sd_" + sd_target

print(list(mydict_sd.keys())[list(mydict_sd.values()).index(sd_target)])

temp_df = pd.DataFrame(df[df[plus_sd_target] >= 1])

temp_df = temp_df[temp_df.length <= 50]

print(temp_df.statement)

pd.DataFrame(temp_df.sd_tags)
# Out:
# quantmod
# 12746    "Rick Scott has destroyed over 100,000 jobs."
# Name: statement, dtype: object
#                                                                                                                                                         sd_tags
# 12746  [(", punct), (Rick, compound), (Scott, nsubj), (has, aux), (destroyed, ROOT), (over, quantmod), (100,000, nummod), (jobs, dobj), (., punct), (", punct)]

# %%
len(sd_df)
# Out:
# 48

# %% [markdown]
# # significantly more likely in truth:
# ### adjectival modifier, determiner, numeric modifier, object of preposition, & prepositional modifier
#
# # significantly more likely in falsehoods:
# ### clausal complement & clausal subject

# %% [markdown]
# # Word Clouds to visualize top words in dataset

# %%
# generate word cloud from first statement we have (#18)
text = df.statement[18]

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# Uncomment to save file
#wordcloud.to_file("all_doc_cloud.png")

# %%
# changing settings
wordcloud = WordCloud(min_font_size=30, 
                      max_font_size=100, 
                      max_words=20, 
                      background_color="white").generate(text)

plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Combine documents
text = " ".join( _ for _ in df.statement)
print ("There are", len(text) ,"words in the combination of all statements.")

# Generate image
wordcloud = WordCloud(min_font_size=24, 
                      max_font_size=1000, 
                      max_words=100, 
                      background_color="white").generate(text)

# Display image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# There are 151823 words in the combination of all statements.

# %%
# wordcloud function for readability
def word_cloud(column):
    
    # Combine documents
    text = " ".join( _ for _ in column)
    
    # Sanity check
    print ("There are", len(text) ,"words")

    # Generate image
    plt.figure(figsize=(12, 10))
    wordcloud = WordCloud(min_font_size=5, 
                          max_font_size=60, 
                          max_words=20, 
                          background_color="white").generate(text)

    # Display the generated image
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## Truth Word Clouds

# %%
word_cloud(df[df.veracity == "True"].statement)
# Out:
# There are 62723 words

# %%
word_cloud(df[df.veracity == "True"].lemmas)
# Out:
# There are 35220 words

# %% [markdown]
# ## Falsehood Word Clouds

# %%
word_cloud(df[df.veracity == "False"].statement)
# Out:
# There are 60153 words

# %%
word_cloud(df[df.veracity == "False"].lemmas)
# Out:
# There are 34563 words

# %% [markdown]
# ## Pants-on-Fire! Word Clouds

# %%
word_cloud(df[df.veracity == "Pants on Fire!"].statement)
# Out:
# There are 28945 words

# %%
word_cloud(df[df.veracity == "Pants on Fire!"].lemmas)
# Out:
# There are 17732 words

# %% [markdown]
# ### I find it odd that all clouds contain the words year and percent
# ### Let's verify with another method

# %%
# counter func and list of words to check
def cnt(col,r):
    # returns total # of times word occured in all statements
    return Counter(col.statement.str.contains(r))[True]

lst = [r"year", r"percent", r"state", r"American", r"half", r"Trump"]

# %%
# frequency func
def freq_check(df):
    # returns word and its frequency
    for r in lst:
        print(r, "freq :", cnt(df, r))

# %%
freq_check(df[df.veracity == "True"])
# Out:
# year freq : 85
# percent freq : 72
# state freq : 76
# American freq : 32
# half freq : 21
# Trump freq : 7

# %%
freq_check(df[df.veracity == "False"])
# Out:
# year freq : 72
# percent freq : 53
# state freq : 40
# American freq : 20
# half freq : 9
# Trump freq : 18

# %%
freq_check(df[df.veracity == "Pants on Fire!"])
# Out:
# year freq : 23
# percent freq : 14
# state freq : 14
# American freq : 8
# half freq : 4
# Trump freq : 29

# %% [markdown]
# ### results of the wordcloud were verified

# %%
# move veracity to the end of the dataframe for convenience
final_df = df[[cols for cols in df if cols not in ['veracity']] + ['veracity']]
final_df[200:1000:200]
# Out:
#             date            source  freq  \
# 2304  2018-02-26  Patrick Morrisey     1
# 3776  2016-12-23   Tdtalliance.com     1
# 6693  2015-02-04    Celine Gounder     1
# 8751  2013-09-30       Bill Nelson     3
#
#                                                                                                                                                                                                     statement  \
# 2304                                                                                                                                                               "The impending work stoppage is unlawful."
# 3776                                                                                                                                                       "Obama orders ban on Christmas cards to military."
# 6693                                                                                                                                 "Measles is one of the most common causes of child blindness worldwide."
# 8751  "Many state and federal agencies have such ‘navigators’ involved in helping folks maneuver through the often complex processes associated with filing benefits claims, for example -- even buying he...
#
#       length  \
# 2304      42
# 3776      50
# 6693      72
# 8751     212
#
#                                                                                                                                    lemmas  \
# 2304                                                                                                     impending work stoppage unlawful
# 3776                                                                                              obama order ban christmas card military
# 6693                                                                                        measle common cause child blindness worldwide
# 8751  state federal agency navigator involve help folk maneuver complex process associate file benefit claim example buy health insurance
#
#                                                                                                                                                                                              general_pos_tags  \
# 2304                                                                           [(", PUNCT), (The, DET), (impending, ADJ), (work, NOUN), (stoppage, NOUN), (is, AUX), (unlawful, ADJ), (., PUNCT), (", PUNCT)]
# 3776                                             [(", PUNCT), (Obama, PROPN), (orders, NOUN), (ban, NOUN), (on, ADP), (Christmas, PROPN), (cards, NOUN), (to, ADP), (military, NOUN), (., PUNCT), (", PUNCT)]
# 6693  [(", PUNCT), (Measles, NOUN), (is, AUX), (one, NUM), (of, ADP), (the, DET), (most, ADV), (common, ADJ), (causes, NOUN), (of, ADP), (child, NOUN), (blindness, NOUN), (worldwide, ADV), (., PUNCT), (...
# 8751  [(", PUNCT), (Many, ADJ), (state, NOUN), (and, CCONJ), (federal, ADJ), (agencies, NOUN), (have, AUX), (such, ADJ), (‘, PUNCT), (navigators, NOUN), (’, PUNCT), (involved, VERB), (in, ADP), (helping...
#
#                                                                                                                                                                                             specific_pos_tags  \
# 2304                                                                                            [(", ``), (The, DT), (impending, JJ), (work, NN), (stoppage, NN), (is, VBZ), (unlawful, JJ), (., .), (", '')]
# 3776                                                                   [(", ``), (Obama, NNP), (orders, NNS), (ban, NN), (on, IN), (Christmas, NNP), (cards, NNS), (to, IN), (military, NN), (., .), (", '')]
# 6693                 [(", ``), (Measles, NNS), (is, VBZ), (one, CD), (of, IN), (the, DT), (most, RBS), (common, JJ), (causes, NNS), (of, IN), (child, NN), (blindness, NN), (worldwide, RB), (., .), (", '')]
# 8751  [(", ``), (Many, JJ), (state, NN), (and, CC), (federal, JJ), (agencies, NNS), (have, VBP), (such, JJ), (‘, ``), (navigators, NNS), (’, ''), (involved, VBN), (in, IN), (helping, VBG), (folks, NNS),...
#
#                                   ner_tags  \
# 2304                                    []
# 3776  [(Obama, PERSON), (Christmas, DATE)]
# 6693                                    []
# 8751                                    []
#
#                                                                                                                                                                                                       sd_tags  \
# 2304                                                                  [(", punct), (The, det), (impending, amod), (work, compound), (stoppage, nsubj), (is, ROOT), (unlawful, acomp), (., punct), (", punct)]
# 3776                                        [(", punct), (Obama, nsubj), (orders, ROOT), (ban, dobj), (on, prep), (Christmas, compound), (cards, pobj), (to, prep), (military, pobj), (., punct), (", punct)]
# 6693  [(", punct), (Measles, nsubj), (is, ROOT), (one, attr), (of, prep), (the, det), (most, advmod), (common, amod), (causes, pobj), (of, prep), (child, compound), (blindness, pobj), (worldwide, advmod...
# 8751  [(", punct), (Many, amod), (state, nmod), (and, cc), (federal, conj), (agencies, nsubj), (have, ROOT), (such, amod), (‘, punct), (navigators, dobj), (’, punct), (involved, acl), (in, prep), (helpi...
#
#       statement_char_count  statement_word_count  statement_avg_word_len  \
# 2304                    42                     6                     6.2
# 3776                    50                     8                     5.4
# 6693                    72                    12                     5.1
# 8751                   212                    30                     6.1
#
#       lemma_char_count  lemma_word_count  lemma_avg_word_len  read_score_gun  \
# 2304                32                 4                 7.2            15.7
# 3776                39                 6                 5.7             8.2
# 6693                45                 6                 6.7             4.8
# 8751               131                18                 6.3            19.9
#
#       pos_adjective  pos_conjunction or particle or adverb  pos_adverb  \
# 2304              2                                      0           0
# 3776              0                                      2           0
# 6693              1                                      2           2
# 8751              4                                      4           2
#
#       pos_coordinating conjuction  pos_determiner  pos_interjection  pos_noun  \
# 2304                            0               1                 0         2
# 3776                            0               0                 0         4
# 6693                            0               1                 0         4
# 8751                            1               1                 0        10
#
#       pos_number  pos_possessive  pos_pronoun  pos_proper noun  \
# 2304           0               0            0                0
# 3776           0               0            0                2
# 6693           1               0            0                0
# 8751           0               0            0                0
#
#       pos_punctuation  pos_space  pos_symbol  pos_verb  pos_unknown  \
# 2304                3          0           0         0            0
# 3776                3          0           0         0            0
# 6693                3          0           0         0            0
# 8751                7          0           0         6            0
#
#       tag_additional word in multi-word expression  tag_adjective  \
# 2304                                             0              2
# 3776                                             0              0
# 6693                                             0              1
# 8751                                             0              4
#
#       tag_adjective (comparative)  tag_adjective (superlative)  tag_adverb  \
# 2304                            0                            0           0
# 3776                            0                            0           0
# 6693                            0                            0           1
# 8751                            0                            0           2
#
#       tag_adverb (comparative)  tag_adverb (particle)  \
# 2304                         0                      0
# 3776                         0                      0
# 6693                         0                      0
# 8751                         0                      0
#
#       tag_adverb (superlative)  tag_affix  tag_cardinal number  \
# 2304                         0          0                    0
# 3776                         0          0                    0
# 6693                         1          0                    1
# 8751                         0          0                    0
#
#       tag_conjunction (coordinating)  \
# 2304                               0
# 3776                               0
# 6693                               0
# 8751                               1
#
#       tag_conjunction (subordinating or preposition)  tag_determiner  \
# 2304                                               0               1
# 3776                                               2               0
# 6693                                               2               1
# 8751                                               4               1
#
#       tag_email  tag_existential there  tag_foreign word  \
# 2304          0                      0                 0
# 3776          0                      0                 0
# 6693          0                      0                 0
# 8751          0                      0                 0
#
#       tag_infinitival “to”  tag_interjection  tag_list item marker  \
# 2304                     0                 0                     0
# 3776                     0                 0                     0
# 6693                     0                 0                     0
# 8751                     0                 0                     0
#
#       tag_missing tag  tag_noun (plural)  tag_noun (proper plural)  \
# 2304                0                  0                         0
# 3776                0                  2                         0
# 6693                0                  2                         0
# 8751                0                  6                         0
#
#       tag_noun (proper singular)  tag_noun (singular or mass)  \
# 2304                           0                            2
# 3776                           2                            2
# 6693                           0                            2
# 8751                           0                            4
#
#       tag_possessive ending  tag_predeterminer  tag_pronoun (personal)  \
# 2304                      0                  0                       0
# 3776                      0                  0                       0
# 6693                      0                  0                       0
# 8751                      0                  0                       0
#
#       tag_pronoun (possessive)  tag_punctuation mark (colon or ellipsis)  \
# 2304                         0                                         0
# 3776                         0                                         0
# 6693                         0                                         0
# 8751                         0                                         1
#
#       tag_punctuation mark (comma)  tag_punctuation mark (hyphen)  \
# 2304                             0                              0
# 3776                             0                              0
# 6693                             0                              0
# 8751                             1                              0
#
#       tag_punctuation mark (sentence closer)  tag_quotation mark (closing)  \
# 2304                                       1                             0
# 3776                                       1                             0
# 6693                                       1                             0
# 8751                                       1                             0
#
#       tag_quotation mark (opening)  tag_round bracket (left)  \
# 2304                             1                         0
# 3776                             1                         0
# 6693                             1                         0
# 8751                             2                         0
#
#       tag_round bracket (right)  tag_space_01  tag_space_02  \
# 2304                          0             0             0
# 3776                          0             0             0
# 6693                          0             0             0
# 8751                          0             0             0
#
#       tag_superfluous punctuation  tag_symbol  tag_symbol (currency)  \
# 2304                            0           0                      0
# 3776                            0           0                      0
# 6693                            0           0                      0
# 8751                            0           0                      0
#
#       tag_unknown  tag_verb (3rd person singular present)  \
# 2304            0                                       1
# 3776            0                                       0
# 6693            0                                       1
# 8751            0                                       0
#
#       tag_verb (base form)  tag_verb (gerund or present participle)  \
# 2304                     0                                        0
# 3776                     0                                        0
# 6693                     0                                        0
# 8751                     1                                        3
#
#       tag_verb (modal or auxiliary)  \
# 2304                              0
# 3776                              0
# 6693                              0
# 8751                              0
#
#       tag_verb (non-3rd person singular present)  tag_verb (past participle)  \
# 2304                                           0                           0
# 3776                                           0                           0
# 6693                                           0                           0
# 8751                                           1                           2
#
#       tag_verb (past tense)  tag_wh-adverb  tag_wh-determiner  \
# 2304                      0              0                  0
# 3776                      0              0                  0
# 6693                      0              0                  0
# 8751                      0              0                  0
#
#       tag_wh-pronoun (personal)  tag_wh-pronoun (possessive)  ner_people  \
# 2304                          0                            0           0
# 3776                          0                            0           1
# 6693                          0                            0           0
# 8751                          0                            0           0
#
#       ner_groups  ner_facilities  ner_organizations  ner_regions  \
# 2304           0               0                  0            0
# 3776           0               0                  0            0
# 6693           0               0                  0            0
# 8751           0               0                  0            0
#
#       ner_landmarks  ner_products  ner_events  ner_art  ner_laws  \
# 2304              0             0           0        0         0
# 3776              0             0           0        0         0
# 6693              0             0           0        0         0
# 8751              0             0           0        0         0
#
#       ner_languages  ner_dates  ner_times  ner_percentages  ner_money  \
# 2304              0          0          0                0          0
# 3776              0          1          0                0          0
# 6693              0          0          0                0          0
# 8751              0          0          0                0          0
#
#       ner_quantity  ner_ordinality  ner_numerals  \
# 2304             0               0             0
# 3776             0               0             0
# 6693             0               0             0
# 8751             0               0             0
#
#       sd_clausal modifier of noun (adjectival clause)  \
# 2304                                                0
# 3776                                                0
# 6693                                                0
# 8751                                                3
#
#       sd_adjectival complement  sd_adverbial clause modifier  \
# 2304                         1                             0
# 3776                         0                             0
# 6693                         0                             0
# 8751                         0                             0
#
#       sd_adverbial modifier  sd_agent  sd_adjectival modifier  \
# 2304                      0         0                       1
# 3776                      0         0                       0
# 6693                      2         0                       1
# 8751                      2         0                       3
#
#       sd_appositional modifier  sd_attribute  sd_auxiliary  \
# 2304                         0             0             0
# 3776                         0             0             0
# 6693                         0             1             0
# 8751                         0             0             0
#
#       sd_auxiliary (passive)  sd_case marking  sd_coordinating conjunction  \
# 2304                       0                0                            0
# 3776                       0                0                            0
# 6693                       0                0                            0
# 8751                       0                0                            1
#
#       sd_clausal complement  sd_compound  sd_conjunct  sd_copula  \
# 2304                      0            1            0          0
# 3776                      0            1            0          0
# 6693                      0            1            0          0
# 8751                      1            3            1          0
#
#       sd_clausal subject  sd_clausal subject (passive)  sd_dative  \
# 2304                   0                             0          0
# 3776                   0                             0          0
# 6693                   0                             0          0
# 8751                   0                             0          0
#
#       sd_unclassified dependent  sd_determiner  sd_direct object  \
# 2304                          0              1                 0
# 3776                          0              0                 1
# 6693                          0              1                 0
# 8751                          0              1                 2
#
#       sd_expletive  sd_interjection  sd_marker  sd_meta modifier  \
# 2304             0                0          0                 0
# 3776             0                0          0                 0
# 6693             0                0          0                 0
# 8751             0                0          0                 0
#
#       sd_negation modifier  sd_noun compound modifier  sd_modifier of nominal  \
# 2304                     0                          0                       0
# 3776                     0                          0                       0
# 6693                     0                          0                       0
# 8751                     0                          0                       0
#
#       sd_noun phrase as adverbial modifier  sd_nominal subject  \
# 2304                                     0                   1
# 3776                                     0                   1
# 6693                                     0                   1
# 8751                                     0                   2
#
#       sd_nominal subject (passive)  sd_numeric modifier  sd_object predicate  \
# 2304                             0                    0                    0
# 3776                             0                    0                    0
# 6693                             0                    0                    0
# 8751                             0                    0                    0
#
#       sd_object  sd_oblique nominal  sd_parataxis  \
# 2304          0                   0             0
# 3776          0                   0             0
# 6693          0                   0             0
# 8751          0                   0             0
#
#       sd_complement of preposition  sd_object of preposition  \
# 2304                             0                         0
# 3776                             0                         2
# 6693                             0                         2
# 8751                             1                         3
#
#       sd_possession modifier  sd_pre-correlative conjunction  \
# 2304                       0                               0
# 3776                       0                               0
# 6693                       0                               0
# 8751                       0                               0
#
#       sd_prepositional modifier  sd_particle  sd_punctuation  \
# 2304                          0            0               3
# 3776                          2            0               3
# 6693                          2            0               3
# 8751                          4            0               7
#
#       sd_modifier of quantifier  sd_relative clause modifier  sd_root  \
# 2304                          0                            0        0
# 3776                          0                            0        0
# 6693                          0                            0        0
# 8751                          0                            0        0
#
#       sd_open clausal complement        veracity
# 2304                           0            True
# 3776                           0  Pants on Fire!
# 6693                           0            True
# 8751                           0            True

# %%
final_df.to_csv("politifact_post_eda")
